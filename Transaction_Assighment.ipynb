# %% [markdown]
# ## Business case:-
# *   The goal of this assignment is to develop an AI-driven system that automates the
# categorization of bank transactions. The categorization should leverage historical data from past
# transactions and payee information. If historical data fails to suggest an appropriate category,
# the system should use OpenAI's APIs to generate an appropriate classification.

# %% [markdown]
# #### Domain :-
# * Finance

# %% [markdown]
# ### Domain Analysis

# %%
import pandas as pd # use for data cleaning
import numpy as np # use for numerical function

# %%
# load the json file
data = pd.read_json("Bank Trasnactions.json") 
data
# Out:
#       Amount                        Bank  \
# 0     290.33        Chase Property #0184
# 1    1000.00  ANZ_Construction Loan_6823
# 2     137.35      American Express #2003
# 3      66.14      American Express #2003
# 4      73.02      American Express #2003
# ..       ...                         ...
# 357     7.05         Bank Australia#0902
# 358     7.06         Bank Australia#0902
# 359     7.24         Bank Australia#0902
# 360     7.50         Bank Australia#0902
# 361   496.15         Bank Australia#0902
#
#                                            Description       Date     Type
# 0        AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428 2024-06-21   Income
# 1    ANZ M-BANKING FUNDS TFER                TRANSF... 2024-11-03  Expense
# 2                  UNIQLO USA LLC NEW YORK NY XXXX2003 2024-11-18  Expense
# 3          LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003 2024-11-18  Expense
# 4    Interest Charge on Pay Over Time Purchases XXX... 2024-11-25  Expense
# ..                                                 ...        ...      ...
# 357  Visa Live Group/8/1 Progress Aeastwood AU#5977... 2024-02-27  Expense
# 358  Visa Lees Farm Eastwood AU#5977439 (Ref.022800... 2024-02-28  Expense
# 359  Visa -Tonkotsuya Carlingford AU#5977439 (Ref.0... 2024-02-02  Expense
# 360  Visa Abdulaziz Radi Shellharbour AU#5977439 (R... 2024-02-29  Expense
# 361  Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.0... 2024-02-11  Expense
#
# [362 rows x 5 columns]

# %%
description_list1 = data["Description"].tolist()
description_list1
# Out:
# ['AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428',
#  'ANZ M-BANKING FUNDS TFER                TRANSFER 642683  TO  XXXXXXXX6546568',
#  'UNIQLO USA LLC NEW YORK NY XXXX2003',
#  'LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003',
#  'Interest Charge on Pay Over Time Purchases XXXX2003',
#  'Interest Charge on Pay Over Time Purchases XXXX2003',
#  'HEINEMANN - 8734 ARRMASCOT AU XXXX2003',
#  'DAVID JONES MACQUARISYDNEY AU XXXX2003',
#  'D J*MW-ONLINE XXX-XXX-2378 NJ XXXX2003',
#  'COMCAST CABLE COMM 800-COMCAST CO XXXX2003',
#  'BING LEE ELECTRICS PSYDNEY AU XXXX2003',
#  'ATP MEDIA WIMBLEDON GB XXXX2003',
#  'AplPay MACQUARIE NORTH RYDE AU XXXX2003',
#  'TINA MAIDS COLORADO SPRINGS CO XXXX2003',
#  'AMAZON MARKETPLACE NAMZN.COM/BILL WA XXXX2011',
#  'MACQUARIE NORTH RYDE AU XXXX2003',
#  'PARAMOUNT+ WEST HOLLYWOO CA XXXX2003',
#  'P.SKOOL.COM/CNMNT EL SEGUNDO CA XXXX2003',
#  'MY SOLO 401K FINANCCARLSBAD CA XXXX2003',
#  'MOUNTAIN VIEW ELECTRLIMON CO XXXX2003',
#  'MOUNTAIN VIEW ELECTRLIMON CO XXXX2003',
#  'MONARCH MONEY APP COVINA CA XXXX2003',
#  'Internet BPAY To American Express - Biller Code 5082 - Receipt No 3521014871',
#  'Net Tfr Received From Sav 12380903 Rec No.: 2566359082',
#  'Net Tfr Received From Sav 12380903. Rec No.:2566359082,',
#  'Direct Credit Tph 1Woo01107Royal',
#  'Visa - Coles 0968 West Ryde AU#5977439 (Ref.012701033732) Apple Pay',
#  'Visa Substock Httpsmaggiesmus#5977439 (Ref.021500042599) Apple Pay',
#  'Viso Substock Httpsmaggiesmus#5977439 (Ref.031500043529) Apple Pay',
#  'Visa Chemist Warehouse Epping AU#5977439 (Ref.022400755199) Apple Pay',
#  'Visa - Substack Httpsmaggiesmus#5977439 (Ref.011500039929) Apple Pay',
#  'Visa - Costis Fresh Seafood Castle Hill AU#5977439 (Ref.011400381784) Apple Pay',
#  'Visa - Amazon AU Sydney South AU#5977439 (Ref.012401226262)',
#  'Visa - Mcdonalds Pmatta Nth North Parramaau#5977439 (Ref.013100557506) Apple Pay',
#  'Visa Sq Bay Cafe At Watsonsbawatsons Bay AU#5977439 (Ref.030501880211) Apple Pay',
#  'Visa Juliesun Pty Ltd North Ryde AU#5977439 (Ref.022600103345) Apple Pay',
#  'Visa Carlingford Public Sch Carlingford AU#5977439 (Ref.032000438700)',
#  'Visa Target 5292 Carlingford AU#5977439 (Ref.022400159612)',
#  'Received From Sav 12450054 Transfer From KC Woolf',
#  'Visa - Boost Castle Towers Castle Hill AU#5977439 (Ref.011100307332) Apple Pay',
#  'Visa OSchoolsonline 0000 Parramatto AU#5977439 (Ref.031901459144)',
#  'Visa Coles 0768 Epping AU#5977439 (Ref.022701966782) Apple Pay',
#  'Visa Smp*Donut King Macquai North Ryde AU#5977439 (Ref.031000581540) Apple Pay',
#  'Visa Petstock Macquarie C North Ryde AU#5977439 (Ref.020200076398) Apple Pay',
#  'Received From Sav 12450054 Transfer From KC Woolf',
#  'Visa - C - Reyes Enterprise Pty Ryde AU#5977439 (Ref.013000135712) Apple Pay',
#  'Visa Chemist Warehouse Eastwood AU#5977439 (Ref.021300203171) Apple Pay',
#  'Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.030901250616) Apple Pay',
#  'Visa Sushi Ru North Ryde AU#5977439 (Ref.030500360590) Apple Pay',
#  'Visa - Coles 0768 Epping AU#5977439 (Ref.011601622997) Apple Pay',
#  'Visa The Greenhouse Centenn Centennial Paau#5977439 (Ref.022600670711) Apple Pay',
#  'Visa Coles 0872 Carlingford AU#5977439 (Ref.022400270586) Apple Pay',
#  'Visa - Mcdonalds Carlingford Carlingford AU#5977439 (Ref.011900947910) Apple Pay',
#  'Visa - Coles 5801 Ryde AU#5977439 (Ref.012900766964) Apple Pay',
#  'Visa - Amazon Marketplace AU Sydney South AU#5977439 (Ref.011901583239)',
#  'Visa - Coles 0951 Baulkham H AU#5977439 (Ref.011901204367) Apple Pay',
#  'Visa Carlingford Public Sch Carlingford AU#5977439 (Ref.032400432086)',
#  'Visa Shoe Club Carlingford AU#5977439 (Ref.021500493278) Apple Pay',
#  'Received From Sav 12450054 Transfer From K C Woolf -',
#  'Visa - Sq *Darcy St Project Cafeepping AU#5977439 (Ref.011701101019) Apple Pay',
#  'Visa Carlingford Public Sch Carlingford AU#5977439
#  'Monthly Account Fee',
#  'Interest Credit',
#  'Visa Aoh Food Trading Pty L Eastwood AU#5977439 (Ref.020900328837) Apple Pay',
#  'Visa The Greenhouse Centenn Centennial Paau#5977439 (Ref.022600670712) Apple Pay',
#  'Visa - Mac Fit Pty Ltd Macquarie Parau#5977439 (Ref.011100886775) Apple Pay',
#  'Viso Freshie Chickens Freshwater AU#5977439 (Ref.020400763993) Apple Pay',
#  'Visa - Pcc Eat Street Parramatta AU#5977439 (Ref.013100734134)',
#  'Visa - Point Parking Pty Ltd North Ryde AU#5977439 (Ref.011600524147)',
#  'Visa - Woolworths/Macquarie S/C North Ryde AU#5977439 (Ref.011601561958) Apple Pay',
#  'Visa Ls The Boothouse Balmo Mosman AU#5977439 (Ref.030701023685) Apple Pay',
#  'Visa - Smp*The Reef Food Bar Collaroy AU#5977439 (Ref.021700070387) Apple Pay',
#  'Visa - Amazon Marketplace AU Sydney South AU#5977439 (Ref.011501086029)',
#  'Direct Credit Tph - 1Woo01121Royal Atc',
#  'Visa Sq *Bonbons Bakery Carlincarlingford AU#5977439 (Ref.022401535333) Apple Pay',
#  'Visa - Aadya Laxmi Pty Ltd Baulkham Hillau#5977439 (Ref.011901370671) Apple Pay',
#  'Visa - Komi Komi Carlingford AU#5977439 (Ref.011801279048) Apple Pay',
#  'Visa Mcdonalds Macquarie North Ryde AU#5977439 (Ref.020200737301) Apple Pay',
#  'Visa - Bronte Surf Life Savin Bronte AU#5977439 (Ref.011500111179) Apple Pay',
#  'Visa - Bronte Surf Life Savin Bronte AU#5977439 (Ref.011500111178) Apple Pay',
#  'Visa Live Group/8/1 Progress Aeastwood AU#5977439 (Ref.022701643205) Apple Pay',
#  'Visa Lees Farm Eastwood AU#5977439 (Ref.022800575866) Apple Pay',
#  'Visa -Tonkotsuya Carlingford AU#5977439 (Ref.020201458678) Apple Pay',
#  'Visa Abdulaziz Radi Shellharbour AU#5977439 (Ref.022900302583) Apple Pay',
#  'Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.021101410748) Apple Pay',
#  'QuickBooks Payments utilizes Rent Income for handling its financial transactions and investments.',
#  'By leveraging Door Lock & Keys, Nextera Energy ensures smooth cash flow for its business operations.',
#  'By leveraging Repairs, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses AAdvantage Aviator to manage its operations efficiently.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Myer-AUD's services.",
#  'Haaretz processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Haaretz settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Appliances account is a vital part of Myer-AUD's financial strategy.",
#  "The AAdvantage Aviator account is a vital part of QuickBooks Payments's financial strategy.",
#  "The Door Lock, Key & Materials account is a vital part of Nextera Energy's financial strategy.",
#  'By leveraging Rent Income, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'Haaretz uses Appliances to manage its operations efficiently.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'By leveraging Door Lock, Key & Materials, Haaretz ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses Door Lock & Keys to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Nextera Energy's services.",
#  'By leveraging Door Lock & Keys, Farha Roofing ensures smooth cash flow for its business operations.',
#  'Superprof settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Vanguard's services.",
#  'Haaretz uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'By leveraging Appliances, Superprof ensures smooth cash flow for its business operations.',
#  "The Repairs account reflects payments and expenditures related to Myer-AUD's services.",
#  'QuickBooks Payments uses Accounts Payable to manage its operations efficiently.',
#  'By leveraging Accounts Payable, Farha Roofing ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses Door Lock & Keys to manage its operations efficiently.',
#  'BANNERMAN ENERGY LTD utilizes Rent Income for handling its financial transactions and investments.',
#  'Farha Roofing utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'By leveraging Accounts Payable, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'By leveraging ANZ_Land Loan Offset_8143, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'SOUNDHOUND AI INC utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'Vanguard uses Accounts Payable to manage its operations efficiently.',
#  'QuickBooks Payments processes payments through Repairs for its ongoing projects.',
#  'Myer-AUD settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'By leveraging Repairs, Vanguard ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Door Lock & Keys account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  'Superprof processes payments through Door Lock & Keys for its ongoing projects.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The Accounts Payable account reflects payments and expenditures related to Myer-AUD's services.",
#  'Myer-AUD processes payments through Appliances for its ongoing projects.',
#  'SOUNDHOUND AI INC uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  'QuickBooks Payments utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Farha Roofing settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Nextera Energy utilizes Accounts Payable for handling its financial transactions and investments.',
#  'Superprof settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'Superprof settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Superprof settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'By leveraging Accounts Payable, Vanguard ensures smooth cash flow for its business operations.',
#  "The Door Lock & Keys account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  'SOUNDHOUND AI INC processes payments through AAdvantage Aviator for its ongoing projects.',
#  'Nextera Energy processes payments through Accounts Payable for its ongoing projects.',
#  'Farha Roofing utilizes Repairs for handling its financial transactions and investments.',
#  'Myer-AUD utilizes Accounts Payable for handling its financial transactions and investments.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  "The Door Lock & Keys account is a vital part of Nextera Energy's financial strategy.",
#  'QuickBooks Payments processes payments through Rent Income for its ongoing projects.',
#  'Haaretz settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'QuickBooks Payments utilizes Appliances for handling its financial transactions and investments.',
#  'Farha Roofing uses Repairs to manage its operations efficiently.',
#  "The Rent Income account reflects payments and expenditures related to Vanguard's services.",
#  'BANNERMAN ENERGY LTD processes payments through AAdvantage Aviator for its ongoing projects.',
#  'Myer-AUD utilizes Repairs for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account is a vital part of QuickBooks Payments's financial strategy.",
#  'QuickBooks Payments utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'By leveraging ANZ_Land Loan Offset_8143, Superprof ensures smooth cash flow for its business operations.',
#  'By leveraging Door Lock & Keys, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Repairs account reflects payments and expenditures related to Vanguard's services.",
#  'BANNERMAN ENERGY LTD processes payments through AAdvantage Aviator for its ongoing projects.',
#  'SOUNDHOUND AI INC uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'Vanguard processes payments through Appliances for its ongoing projects.',
#  "The Door Lock, Key & Materials account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  'Vanguard utilizes Accounts Payable for handling its financial transactions and investments.',
#  'By leveraging Repairs, Haaretz ensures smooth cash flow for its business operations.',
#  'Haaretz utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Myer-AUD uses Door Lock & Keys to manage its operations efficiently.',
#  "The Appliances account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  'QuickBooks Payments processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'SOUNDHOUND AI INC processes payments through AAdvantage Aviator for its ongoing projects.',
#  "The Repair & Maintenance - AUD account is a vital part of Superprof's financial strategy.",
#  'By leveraging AAdvantage Aviator, Superprof ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account is a vital part of Farha Roofing's financial strategy.",
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Myer-AUD uses Repairs to manage its operations efficiently.',
#  'Vanguard processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'BANNERMAN ENERGY LTD uses Repairs to manage its operations efficiently.',
#  'Superprof uses Door Lock, Key & Materials to manage its operations efficiently.',
#  "The Repair & Maintenance - AUD account is a vital part of Myer-AUD's financial strategy.",
#  'Nextera Energy uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'QuickBooks Payments utilizes Accounts Payable for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'Nextera Energy uses Appliances to manage its operations efficiently.',
#  "The Door Lock, Key & Materials account is a vital part of QuickBooks Payments's financial strategy.",
#  'Haaretz processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Vanguard processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Nextera Energy's services.",
#  "The Repair & Maintenance - AUD account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD uses Rent Income to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account is a vital part of Myer-AUD's financial strategy.",
#  'By leveraging Accounts Payable, Haaretz ensures smooth cash flow for its business operations.',
#  'Myer-AUD settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'QuickBooks Payments processes payments through Rent Income for its ongoing projects.',
#  'Haaretz utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'Myer-AUD settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  "The Repairs account is a vital part of Farha Roofing's financial strategy.",
#  'Farha Roofing utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Haaretz's services.",
#  'Haaretz uses Door Lock & Keys to manage its operations efficiently.',
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'By leveraging ANZ_Land Loan Offset_8143, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'Myer-AUD utilizes Rent Income for handling its financial transactions and investments.',
#  "The Repairs account reflects payments and expenditures related to Nextera Energy's services.",
#  'Superprof processes payments through Accounts Payable for its ongoing projects.',
#  'Superprof uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'QuickBooks Payments settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'By leveraging Door Lock, Key & Materials, Nextera Energy ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments processes payments through AAdvantage Aviator for its ongoing projects.',
#  'Superprof settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'By leveraging AAdvantage Aviator, Haaretz ensures smooth cash flow for its business operations.',
#  'Superprof settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  "The Repairs account reflects payments and expenditures related to Myer-AUD's services.",
#  'Vanguard settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  "The Door Lock & Keys account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Superprof processes payments through Accounts Payable for its ongoing projects.',
#  "The Rent Income account is a vital part of Myer-AUD's financial strategy.",
#  'Myer-AUD processes payments through Accounts Payable for its ongoing projects.',
#  'Haaretz utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'By leveraging Door Lock & Keys, Haaretz ensures smooth cash flow for its business operations.',
#  'By leveraging Repair & Maintenance - AUD, Superprof ensures smooth cash flow for its business operations.',
#  "The Repair & Maintenance - AUD account is a vital part of Nextera Energy's financial strategy.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'By leveraging Repairs, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Farha Roofing settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Nextera Energy utilizes Repairs for handling its financial transactions and investments.',
#  'By leveraging Appliances, Vanguard ensures smooth cash flow for its business operations.',
#  'Superprof uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'By leveraging ANZ_Land Loan Offset_8143, Nextera Energy ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'By leveraging Rent Income, Haaretz ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD uses Repairs to manage its operations efficiently.',
#  'Superprof uses AAdvantage Aviator to manage its operations efficiently.',
#  'Nextera Energy processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Vanguard uses AAdvantage Aviator to manage its operations efficiently.',
#  'Farha Roofing processes payments through Repairs for its ongoing projects.',
#  'BANNERMAN ENERGY LTD utilizes Accounts Payable for handling its financial transactions and investments.',
#  "The Repairs account reflects payments and expenditures related to Vanguard's services.",
#  'Vanguard settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  "The Rent Income account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  'BANNERMAN ENERGY LTD processes payments through Repairs for its ongoing projects.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Myer-AUD's services.",
#  'SOUNDHOUND AI INC processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Farha Roofing's services.",
#  'QuickBooks Payments utilizes Repairs for handling its financial transactions and investments.',
#  "The Door Lock & Keys account is a vital part of Nextera Energy's financial strategy.",
#  "The AAdvantage Aviator account reflects payments and expenditures related to Vanguard's services.",
#  'Nextera Energy uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'By leveraging Rent Income, Myer-AUD ensures smooth cash flow for its business operations.',
#  "The Rent Income account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Nextera Energy settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  "The Rent Income account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'Farha Roofing utilizes Accounts Payable for handling its financial transactions and investments.',
#  "The AAdvantage Aviator account is a vital part of Farha Roofing's financial strategy.",
#  "The Repairs account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  'SOUNDHOUND AI INC utilizes Appliances for handling its financial transactions and investments.',
#  'By leveraging Repairs, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'Myer-AUD utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  "The AAdvantage Aviator account is a vital part of Vanguard's financial strategy.",
#  'By leveraging Repair & Maintenance - AUD, Farha Roofing ensures smooth cash flow for its business operations.',
#  "The AAdvantage Aviator account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Vanguard utilizes Repairs for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'Farha Roofing utilizes Appliances for handling its financial transactions and investments.',
#  'By leveraging Accounts Payable, Myer-AUD ensures smooth cash flow for its business operations.',
#  "The Appliances account reflects payments and expenditures related to Farha Roofing's services.",
#  'SOUNDHOUND AI INC settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'By leveraging Accounts Payable, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Farha Roofing utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  "The Repairs account is a vital part of Myer-AUD's financial strategy.",
#  'SOUNDHOUND AI INC uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'SOUNDHOUND AI INC settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The Door Lock, Key & Materials account reflects payments and expenditures related to Haaretz's services.",
#  'Myer-AUD processes payments through AAdvantage Aviator for its ongoing projects.',
#  'BANNERMAN ENERGY LTD utilizes Repairs for handling its financial transactions and investments.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Nextera Energy's services.",
#  'Nextera Energy settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'By leveraging AAdvantage Aviator, Vanguard ensures smooth cash flow for its business operations.',
#  'Superprof utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Repairs account is a vital part of QuickBooks Payments's financial strategy.",
#  'Farha Roofing utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account is a vital part of Vanguard's financial strategy.",
#  "The Rent Income account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Nextera Energy utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  'Myer-AUD processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  "The Accounts Payable account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'By leveraging AAdvantage Aviator, Haaretz ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses Appliances to manage its operations efficiently.',
#  'QuickBooks Payments uses Door Lock & Keys to manage its operations efficiently.',
#  'QuickBooks Payments utilizes Rent Income for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Repairs for its ongoing projects.',
#  "The Door Lock & Keys account is a vital part of QuickBooks Payments's financial strategy.",
#  'QuickBooks Payments processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'SOUNDHOUND AI INC utilizes Appliances for handling its financial transactions and investments.',
#  'By leveraging Appliances, Farha Roofing ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'By leveraging AAdvantage Aviator, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Door Lock, Key & Materials account reflects payments and expenditures related to Farha Roofing's services.",
#  'Farha Roofing settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'BANNERMAN ENERGY LTD utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'Superprof uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Myer-AUD's services.",
#  'SOUNDHOUND AI INC processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'By leveraging Repairs, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'By leveraging Accounts Payable, Superprof ensures smooth cash flow for its business operations.',
#  'Haaretz utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'Myer-AUD processes payments through Door Lock & Keys for its ongoing projects.',
#  "The Repair & Maintenance - AUD account is a vital part of Haaretz's financial strategy.",
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Farha Roofing processes payments through Rent Income for its ongoing projects.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  'Haaretz utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Haaretz processes payments through Rent Income for its ongoing projects.',
#  'Vanguard uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  "The Repairs account reflects payments and expenditures related to Superprof's services.",
#  'By leveraging ANZ_Land Loan Offset_8143, Superprof ensures smooth cash flow for its business operations.',
# ...
#  'By leveraging Door Lock, Key & Materials, Nextera Energy ensures smooth cash flow for its business operations.',
#  'By leveraging Repair & Maintenance - AUD, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The AAdvantage Aviator account is a vital part of Vanguard's financial strategy.",
#  'By leveraging Repair & Maintenance - AUD, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  'QuickBooks Payments settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  'QuickBooks Payments settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Haaretz utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  'Vanguard uses Accounts Payable to manage its operations efficiently.',
#  'By leveraging AAdvantage Aviator, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  "The Repairs account is a vital part of Haaretz's financial strategy.",
#  "The Repairs account is a vital part of Farha Roofing's financial strategy.",
#  "The Rent Income account reflects payments and expenditures related to Vanguard's services.",
#  "The Appliances account is a vital part of Superprof's financial strategy.",
#  'By leveraging Repair & Maintenance - AUD, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  "The Repair & Maintenance - AUD account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  'Haaretz uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Farha Roofing settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'Superprof utilizes Repairs for handling its financial transactions and investments.',
#  'By leveraging Appliances, Haaretz ensures smooth cash flow for its business operations.',
#  'Superprof processes payments through Door Lock & Keys for its ongoing projects.',
#  'Vanguard utilizes Repairs for handling its financial transactions and investments.',
#  'By leveraging Rent Income, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account reflects payments and expenditures related to Farha Roofing's services.",
#  'Nextera Energy uses Rent Income to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Myer-AUD's services.",
#  'BANNERMAN ENERGY LTD uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Nextera Energy utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'Vanguard processes payments through Appliances for its ongoing projects.',
#  'QuickBooks Payments uses Appliances to manage its operations efficiently.',
#  'Superprof uses Door Lock & Keys to manage its operations efficiently.',
#  'Haaretz utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  'By leveraging Repair & Maintenance - AUD, Farha Roofing ensures smooth cash flow for its business operations.',
#  "The Appliances account is a vital part of Farha Roofing's financial strategy.",
#  'SOUNDHOUND AI INC utilizes Appliances for handling its financial transactions and investments.',
#  'QuickBooks Payments settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  'QuickBooks Payments uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  "The Repairs account reflects payments and expenditures related to Vanguard's services.",
#  "The Repairs account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing uses Appliances to manage its operations efficiently.',
#  'By leveraging Door Lock & Keys, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'Farha Roofing utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Haaretz settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'Superprof utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'By leveraging AAdvantage Aviator, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  'By leveraging Accounts Payable, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account is a vital part of QuickBooks Payments's financial strategy.",
#  'Nextera Energy processes payments through Appliances for its ongoing projects.',
#  "The Door Lock & Keys account is a vital part of Myer-AUD's financial strategy.",
#  "The Repairs account reflects payments and expenditures related to Superprof's services.",
#  'Vanguard processes payments through Door Lock & Keys for its ongoing projects.',
#  'Farha Roofing utilizes Accounts Payable for handling its financial transactions and investments.',
#  'Myer-AUD utilizes Accounts Payable for handling its financial transactions and investments.',
#  'Myer-AUD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Appliances account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'Haaretz settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'SOUNDHOUND AI INC processes payments through Door Lock & Keys for its ongoing projects.',
#  'BANNERMAN ENERGY LTD uses Door Lock & Keys to manage its operations efficiently.',
#  'Vanguard settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'By leveraging Door Lock & Keys, Myer-AUD ensures smooth cash flow for its business operations.',
#  'Vanguard settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'By leveraging Appliances, Haaretz ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  "The Repairs account reflects payments and expenditures related to Superprof's services.",
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Superprof's services.",
#  'QuickBooks Payments utilizes Repairs for handling its financial transactions and investments.',
#  "The Rent Income account is a vital part of Nextera Energy's financial strategy.",
#  'Haaretz utilizes Accounts Payable for handling its financial transactions and investments.',
#  'BANNERMAN ENERGY LTD uses AAdvantage Aviator to manage its operations efficiently.',
#  'Vanguard settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Door Lock, Key & Materials account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  "The Appliances account reflects payments and expenditures related to Farha Roofing's services.",
#  'By leveraging Door Lock, Key & Materials, Nextera Energy ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'Nextera Energy utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Superprof processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'By leveraging Rent Income, Nextera Energy ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'By leveraging Rent Income, Farha Roofing ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD utilizes Door Lock, Key & Materials for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Nextera Energy's services.",
#  'BANNERMAN ENERGY LTD processes payments through Rent Income for its ongoing projects.',
#  "The Accounts Payable account reflects payments and expenditures related to Myer-AUD's services.",
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  "The Accounts Payable account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  "The Repair & Maintenance - AUD account is a vital part of Haaretz's financial strategy.",
#  'Vanguard uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Superprof uses Appliances to manage its operations efficiently.',
#  'By leveraging Accounts Payable, Vanguard ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, Vanguard ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'Farha Roofing processes payments through Repairs for its ongoing projects.',
#  'SOUNDHOUND AI INC uses Door Lock & Keys to manage its operations efficiently.',
#  'SOUNDHOUND AI INC utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Door Lock, Key & Materials account is a vital part of Superprof's financial strategy.",
#  'Superprof settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'By leveraging Repair & Maintenance - AUD, Myer-AUD ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'QuickBooks Payments uses Door Lock & Keys to manage its operations efficiently.',
#  'Farha Roofing uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'Superprof settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'Superprof processes payments through Door Lock & Keys for its ongoing projects.',
#  'Haaretz uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'QuickBooks Payments settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Myer-AUD's services.",
#  'Myer-AUD uses Rent Income to manage its operations efficiently.',
#  'Superprof settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'QuickBooks Payments settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  "The Accounts Payable account reflects payments and expenditures related to Nextera Energy's services.",
#  'Vanguard utilizes Appliances for handling its financial transactions and investments.',
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  'By leveraging Appliances, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Haaretz processes payments through Door Lock & Keys for its ongoing projects.',
#  "The Appliances account is a vital part of Farha Roofing's financial strategy.",
#  'QuickBooks Payments utilizes Appliances for handling its financial transactions and investments.',
#  'QuickBooks Payments uses Door Lock, Key & Materials to manage its operations efficiently.',
#  "The Appliances account is a vital part of Haaretz's financial strategy.",
#  'By leveraging ANZ_Land Loan Offset_8143, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Nextera Energy's services.",
#  'Nextera Energy settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'Farha Roofing processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Farha Roofing settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  "The Appliances account reflects payments and expenditures related to Nextera Energy's services.",
#  "The AAdvantage Aviator account reflects payments and expenditures related to Vanguard's services.",
#  'Farha Roofing uses Appliances to manage its operations efficiently.',
#  "The Door Lock & Keys account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  "The Door Lock, Key & Materials account is a vital part of Haaretz's financial strategy.",
#  'By leveraging Repairs, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'By leveraging Repair & Maintenance - AUD, Superprof ensures smooth cash flow for its business operations.',
#  'Nextera Energy uses Accounts Payable to manage its operations efficiently.',
#  "The AAdvantage Aviator account is a vital part of Haaretz's financial strategy.",
#  "The Appliances account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  "The AAdvantage Aviator account is a vital part of Vanguard's financial strategy.",
#  'BANNERMAN ENERGY LTD utilizes Door Lock, Key & Materials for handling its financial transactions and investments.',
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Nextera Energy's services.",
#  'BANNERMAN ENERGY LTD processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'Farha Roofing processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Superprof processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  "The Appliances account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'Myer-AUD utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'QuickBooks Payments settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The AAdvantage Aviator account reflects payments and expenditures related to Nextera Energy's services.",
#  "The Rent Income account reflects payments and expenditures related to Vanguard's services.",
#  'BANNERMAN ENERGY LTD uses Repairs to manage its operations efficiently.',
#  'Superprof uses Repairs to manage its operations efficiently.',
#  'SOUNDHOUND AI INC uses Accounts Payable to manage its operations efficiently.',
#  'By leveraging Repair & Maintenance - AUD, Superprof ensures smooth cash flow for its business operations.',
#  "The Repairs account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'QuickBooks Payments utilizes Door Lock, Key & Materials for handling its financial transactions and investments.',
#  'QuickBooks Payments settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The AAdvantage Aviator account is a vital part of QuickBooks Payments's financial strategy.",
#  'Superprof uses Accounts Payable to manage its operations efficiently.',
#  "The Appliances account is a vital part of Haaretz's financial strategy.",
#  ...]

# %% [markdown]
# **Attribute Inforamtion:-**
#
# **Amount:** The numerical value associated with a transaction or an entry, typically representing the amount of money involved.
#
# **Bank:** The name of the financial institution or bank associated with the transaction.
#
# **Description:** A brief explanation or details about the transaction, such as what the payment was for (e.g., "Payment for services" or "Deposit").
#
# **Date:** The date when the transaction occurred, often formatted as YYYY-MM-DD or MM/DD/YYYY, depending on the region.
#
# **Type:** This likely indicates the nature of the transaction. It could be values such as:

# %%
# load the json file
data1 = pd.read_json("Charts of Accounts.json")
data1
# Out:
#           AccountType Classification          FullyQualifiedName  \
# 0         Credit Card      Liability          AAdvantage Aviator
# 1    Accounts Payable      Liability            Accounts Payable
# 2                Bank          Asset   ANZ_Land Loan Offset_8143
# 3              Income        Revenue           RENTS:Rent Income
# 4             Expense        Expense  Repair & Maintenance - Aud
# ..                ...            ...                         ...
# 141           Expense        Expense                 Tax Payment
# 142              Bank          Asset         Bank Australia 0054
# 143              Bank          Asset         Bank Australia 0903
# 144              Bank          Asset         Bank Australia 5523
# 145              Bank          Asset         Bank Australia#0902
#
#                            Name
# 0            AAdvantage Aviator
# 1              Accounts Payable
# 2     ANZ_Land Loan Offset_8143
# 3                   Rent Income
# 4    Repair & Maintenance - Aud
# ..                          ...
# 141                 Tax Payment
# 142         Bank Australia 0054
# 143         Bank Australia 0903
# 144         Bank Australia 5523
# 145         Bank Australia#0902
#
# [146 rows x 4 columns]

# %%
data1["AccountType"].unique()
# Out:
# array(['Credit Card', 'Accounts Payable', 'Bank', 'Income', 'Expense',
#        'Equity', 'Other Current Asset', 'Other Expense',
#        'Accounts Receivable', 'Cost of Goods Sold', 'Other Income',
#        'Other Asset', 'Other Current Liability'], dtype=object)

# %% [markdown]
# **Attribute Information:-**
#
# **AccountType:** Defines the type of account (e.g., Checking, Savings).
#
# **Classification:** Categorizes the account or transaction (e.g., Personal, Business).
#
# **FullyQualifiedName:** Provides a precise and unique identifier for the account or entity.
#
# **Name:** Represents the name of the account holder or entity.

# %%
# load the json file
data2 = pd.read_json("Payee.json")
data2
# Out:
#                       Name                          Account 1 Account 2  \
# 0        SOUNDHOUND AI INC                Investment Accounts
# 1           Nextera Energy                Investment Accounts  Dividend
# 2                 Vanguard       Investment Accounts:Vanguard
# 3                Superprof  Household:Health,Fitness,Personal
# 4                  Haaretz             Dues and Subscriptions
# ..                     ...                                ...       ...
# 501  Strike Bowling Castle
# 502            Safety Wing
# 503            Boost Juice
# 504             Trybooking
# 505           Patio Putney
#
#     Account 3
# 0
# 1
# 2
# 3
# 4
# ..        ...
# 501
# 502
# 503
# 504
# 505
#
# [506 rows x 4 columns]

# %% [markdown]
# **Attribute Information:-**
#
# **Name:** Represents the name of the account holder or the entity. This could be the name of an individual or business associated with the accounts.
#
# **Account 1:** Could represent a checking account, savings account, or any other type of account.
#
# **Account 2:** Another account, perhaps a different type or used for a different purpose (e.g., business or personal).
#
# **Account 3:** Yet another account, which could be linked to a separate financial activity, like an investment account or a credit account.

# %%
data2.replace("", "Not Found", inplace=True) # use dor replace null value in not found

# %%
data2
# Out:
#                       Name                          Account 1  Account 2  \
# 0        SOUNDHOUND AI INC                Investment Accounts  Not Found
# 1           Nextera Energy                Investment Accounts   Dividend
# 2                 Vanguard       Investment Accounts:Vanguard  Not Found
# 3                Superprof  Household:Health,Fitness,Personal  Not Found
# 4                  Haaretz             Dues and Subscriptions  Not Found
# ..                     ...                                ...        ...
# 501  Strike Bowling Castle                          Not Found  Not Found
# 502            Safety Wing                          Not Found  Not Found
# 503            Boost Juice                          Not Found  Not Found
# 504             Trybooking                          Not Found  Not Found
# 505           Patio Putney                          Not Found  Not Found
#
#      Account 3
# 0    Not Found
# 1    Not Found
# 2    Not Found
# 3    Not Found
# 4    Not Found
# ..         ...
# 501  Not Found
# 502  Not Found
# 503  Not Found
# 504  Not Found
# 505  Not Found
#
# [506 rows x 4 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# * Feature Engineering is the process of using domain knowledge, creativity, and data manipulation techniques to transform raw data into features (or variables) that can improve the performance of machine learning models.
#
# * In simple terms, it involves:
#
# 1. Creating new features from existing data (e.g., combining two columns, extracting parts of a string, creating time-based features like day of the week).
# 2. Transforming features to better represent the underlying patterns (e.g., normalizing, scaling, or encoding categorical variables).
# 3. Selecting important features to improve model accuracy and reduce overfitting.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# * Data Preprocessing is the process of preparing raw data for analysis or machine learning by cleaning, transforming, and organizing it in a way that enhances the accuracy and efficiency of models. It typically involves the following steps:

# %%
# merge the data
import pandas as pd

# Load datasets
df1 = pd.read_json("Charts of Accounts.json")  # First dataset
df2 = pd.read_json("Payee.json")  # Second dataset

# Perform row-wise merge (only matching rows) based on a common column (e.g., "ID")
merged_df = pd.merge(df1, df2, on="Name", how="outer")  # Inner join keeps only matches

# Save the merged file
merged_df.to_csv("Merged_Dataset.csv", index=False)

print("✅ Merging complete! Only matching rows are retained.")
# Out:
# ✅ Merging complete! Only matching rows are retained.

# %%
dff = pd.read_csv("Merged_Dataset.csv") # load the csv file
dff
# Out:
#           AccountType Classification          FullyQualifiedName  \
# 0         Credit Card      Liability          AAdvantage Aviator
# 1    Accounts Payable      Liability            Accounts Payable
# 2                Bank          Asset   ANZ_Land Loan Offset_8143
# 3              Income        Revenue           RENTS:Rent Income
# 4             Expense        Expense  Repair & Maintenance - Aud
# ..                ...            ...                         ...
# 646               NaN            NaN                         NaN
# 647               NaN            NaN                         NaN
# 648               NaN            NaN                         NaN
# 649               NaN            NaN                         NaN
# 650               NaN            NaN                         NaN
#
#                            Name Account 1 Account 2 Account 3
# 0            AAdvantage Aviator       NaN       NaN       NaN
# 1              Accounts Payable       NaN       NaN       NaN
# 2     ANZ_Land Loan Offset_8143       NaN       NaN       NaN
# 3                   Rent Income       NaN       NaN       NaN
# 4    Repair & Maintenance - Aud       NaN       NaN       NaN
# ..                          ...       ...       ...       ...
# 646       Strike Bowling Castle       NaN       NaN       NaN
# 647                 Safety Wing       NaN       NaN       NaN
# 648                 Boost Juice       NaN       NaN       NaN
# 649                  Trybooking       NaN       NaN       NaN
# 650                Patio Putney       NaN       NaN       NaN
#
# [651 rows x 7 columns]

# %%
# matched_name or Account match value based on Description 
import pandas as pd

# Load Bank Transactions (JSON)
data = pd.read_json("Bank Trasnactions.json")

# Load Payee Data (CSV) - Make sure it contains "Name" and "Account 1"
data2 = pd.read_csv("Payee.csv")  

# Handle missing values
data["Description"] = data["Description"].fillna("Not Found")  # Prevent NaN issues
data2["Name"] = data2["Name"].fillna("Not Found")  
data2["Account 1"] = data2["Account 1"].fillna("Not Found")  # Ensure Account 1 has values

# Convert Name column into a dictionary {Name: Account 1} for fast lookup
name_to_account = dict(zip(data2["Name"], data2["Account 1"]))

# Function to find a matching Name and return Account 1
def find_match_and_account(description, reference_dict):
    for name, account in reference_dict.items():
        if name.lower() in description.lower():  # Case insensitive matching
            return name, account  # Return matched name and its corresponding Account 1
    return "No Found", "Not Found"  # Default if no match is found

# Apply function to find matches
data[["Matched_Name", "Account 1"]] = data["Description"].apply(
    lambda x: pd.Series(find_match_and_account(x, name_to_account))
)

# Display the result
print(data)

# Save results to a new file
data.to_csv("Categorized_Transactions.csv", index=False)
print("✅ Process completed! Results saved to Categorized_Transactions.csv")
# Out:
#       Amount                        Bank  \
# 0     290.33        Chase Property #0184
# 1    1000.00  ANZ_Construction Loan_6823
# 2     137.35      American Express #2003
# 3      66.14      American Express #2003
# 4      73.02      American Express #2003
# ..       ...                         ...
# 357     7.05         Bank Australia#0902
# 358     7.06         Bank Australia#0902
# 359     7.24         Bank Australia#0902
# 360     7.50         Bank Australia#0902
# 361   496.15         Bank Australia#0902
#
#                                            Description       Date     Type  \
# 0        AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428 2024-06-21   Income
# 1    ANZ M-BANKING FUNDS TFER                TRANSF... 2024-11-03  Expense
# 2                  UNIQLO USA LLC NEW YORK NY XXXX2003 2024-11-18  Expense
# 3          LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003 2024-11-18  Expense
# 4    Interest Charge on Pay Over Time Purchases XXX... 2024-11-25  Expense
# ..                                                 ...        ...      ...
# 357  Visa Live Group/8/1 Progress Aeastwood AU#5977... 2024-02-27  Expense
# 358  Visa Lees Farm Eastwood AU#5977439 (Ref.022800... 2024-02-28  Expense
# 359  Visa -Tonkotsuya Carlingford AU#5977439 (Ref.0... 2024-02-02  Expense
# 360  Visa Abdulaziz Radi Shellharbour AU#5977439 (R... 2024-02-29  Expense
# 361  Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.0... 2024-02-11  Expense
#
#     Matched_Name                          Account 1
# 0         AirBnB                      Rental Income
# 1       No Found                          Not Found
# 2         Uniqlo  Household:Health,Fitness,Personal
# 3           LIDS  Household:Health,Fitness,Personal
# 4       No Found                          Not Found
# ..           ...                                ...
# 357        Apple                          Not Found
# 358        Apple                          Not Found
# 359   Tonkotsuya            Meals and Entertainment
# 360        Apple                          Not Found
# 361        Coles                Household:Groceries
#
# [362 rows x 7 columns]
# ✅ Process completed! Results saved to Categorized_Transactions.csv

# %%
df = pd.read_csv("Categorized_Transactions.csv") # load the CSV File
df.iloc[:,2:]
# Out:
#                                            Description        Date     Type  \
# 0        AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428  2024-06-21   Income
# 1    ANZ M-BANKING FUNDS TFER                TRANSF...  2024-11-03  Expense
# 2                  UNIQLO USA LLC NEW YORK NY XXXX2003  2024-11-18  Expense
# 3          LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003  2024-11-18  Expense
# 4    Interest Charge on Pay Over Time Purchases XXX...  2024-11-25  Expense
# ..                                                 ...         ...      ...
# 357  Visa Live Group/8/1 Progress Aeastwood AU#5977...  2024-02-27  Expense
# 358  Visa Lees Farm Eastwood AU#5977439 (Ref.022800...  2024-02-28  Expense
# 359  Visa -Tonkotsuya Carlingford AU#5977439 (Ref.0...  2024-02-02  Expense
# 360  Visa Abdulaziz Radi Shellharbour AU#5977439 (R...  2024-02-29  Expense
# 361  Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.0...  2024-02-11  Expense
#
#     Matched_Name                          Account 1
# 0         AirBnB                      Rental Income
# 1       No Found                          Not Found
# 2         Uniqlo  Household:Health,Fitness,Personal
# 3           LIDS  Household:Health,Fitness,Personal
# 4       No Found                          Not Found
# ..           ...                                ...
# 357        Apple                          Not Found
# 358        Apple                          Not Found
# 359   Tonkotsuya            Meals and Entertainment
# 360        Apple                          Not Found
# 361        Coles                Household:Groceries
#
# [362 rows x 5 columns]

# %%
# drop the invalid Column
dff2 = df.drop(["Amount","Bank","Date","Type"],axis=1)
dff2
cv =  dff2.to_csv("Hello.csv")
cv

# %%
cv1 = pd.read_csv("Hello.csv") # load the csv file
cv1
# Out:
#      Unnamed: 0                                        Description  \
# 0             0      AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428
# 1             1  ANZ M-BANKING FUNDS TFER                TRANSF...
# 2             2                UNIQLO USA LLC NEW YORK NY XXXX2003
# 3             3        LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003
# 4             4  Interest Charge on Pay Over Time Purchases XXX...
# ..          ...                                                ...
# 357         357  Visa Live Group/8/1 Progress Aeastwood AU#5977...
# 358         358  Visa Lees Farm Eastwood AU#5977439 (Ref.022800...
# 359         359  Visa -Tonkotsuya Carlingford AU#5977439 (Ref.0...
# 360         360  Visa Abdulaziz Radi Shellharbour AU#5977439 (R...
# 361         361  Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.0...
#
#     Matched_Name                          Account 1
# 0         AirBnB                      Rental Income
# 1       No Found                          Not Found
# 2         Uniqlo  Household:Health,Fitness,Personal
# 3           LIDS  Household:Health,Fitness,Personal
# 4       No Found                          Not Found
# ..           ...                                ...
# 357        Apple                          Not Found
# 358        Apple                          Not Found
# 359   Tonkotsuya            Meals and Entertainment
# 360        Apple                          Not Found
# 361        Coles                Household:Groceries
#
# [362 rows x 4 columns]

# %% [markdown]
# ## Model Selection

# %% [markdown]
# * Model Selection is the process of choosing the best machine learning model from a set of candidate models for a given task, based on criteria like performance, efficiency, and suitability for the problem. This step is critical because the choice of model directly affects the quality of predictions and the accuracy of your results.

# %% [markdown]
# ## RandomForest Classification Algorithm

# %% [markdown]
# * Random Forest Classification is a powerful ensemble learning algorithm used for solving classification problems. It works by constructing a collection of decision trees during the training phase, where each tree is trained on a random subset of the data, using a technique called bootstrapping. This approach ensures that each tree is exposed to slightly different data, promoting diversity among the trees and preventing overfitting. Additionally, at each split in the trees, a random subset of features is selected, further enhancing the model's robustness. When making predictions, the model aggregates the outputs of all trees through majority voting, where the class predicted by most trees is chosen as the final prediction.
#
# * Random Forest is known for its high accuracy, ability to handle large datasets with many features, and its resilience to overfitting, making it suitable for a wide range of classification tasks, such as medical diagnosis, customer segmentation, and image classification. However, while it offers high performance, it can be computationally expensive and difficult to interpret due to the complexity of combining multiple decision trees.

# %%
import pandas as pd # use for Data manipalution
import re # use for reguler exprression
from sklearn.model_selection import train_test_split # use for train and test data
from sklearn.feature_extraction.text import TfidfVectorizer # use for categorical to numerical vectore
from sklearn.ensemble import RandomForestClassifier # import RM Algorithm
from sklearn.pipeline import Pipeline # create a custom pipline 
from sklearn.metrics import accuracy_score # use for model evaluation

# Load dataset (replace with actual file)
file_path = "Categorized_Transactions.csv"
data = pd.read_csv(file_path)

# Ensure required columns exist
required_columns = ["Description", "Matched_Name", "Account 1"]
for col in required_columns:
    if col not in data.columns:
        raise ValueError(f"Missing required column: {col} in the dataset")

# Fill missing values
data["Description"] = data["Description"].fillna("Unknown")
data["Matched_Name"] = data["Matched_Name"].fillna("Not Found")
data["Account 1"] = data["Account 1"].fillna("Not Found")

# Clean text (Remove numbers, special characters)
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text.strip()

data["Cleaned_Description"] = data["Description"].apply(clean_text)

# Split dataset
X_train, X_test, y_train_name, y_test_name = train_test_split(data["Cleaned_Description"], data["Matched_Name"], test_size=0.2, random_state=42)
X_train, X_test, y_train_acc, y_test_acc = train_test_split(data["Cleaned_Description"], data["Account 1"], test_size=0.2, random_state=42)

# Create TF-IDF Vectorizer + Random Forest Pipeline
model_name = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', RandomForestClassifier(n_estimators=100, random_state=42))
])

model_acc = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', RandomForestClassifier(n_estimators=100, random_state=42))
])

# Train models
print("Training 'Matched_Name' model...")
model_name.fit(X_train, y_train_name)

print("Training 'Account 1' model...")
model_acc.fit(X_train, y_train_acc)

# Predict on test set
y_pred_name = model_name.predict(X_test)
y_pred_acc = model_acc.predict(X_test)

# Evaluate accuracy
print(f"'Matched_Name' Accuracy: {accuracy_score(y_test_name, y_pred_name):.2f}")
print(f"'Account 1' Accuracy: {accuracy_score(y_test_acc, y_pred_acc):.2f}")

# Function to predict new descriptions
def classify_transaction(description):
    cleaned_desc = clean_text(description)
    matched_name_pred = model_name.predict([cleaned_desc])[0]
    account_pred = model_acc.predict([cleaned_desc])[0]
    return matched_name_pred, account_pred

# Example Usage
description = "UNIQLO USA LLC NEW YORK NY XXXX2003"
matched_name, account_category = classify_transaction(description)
print(f"Predicted Matched_Name: {matched_name}")
print(f"Predicted Account 1: {account_category}")
# Out:
# Training 'Matched_Name' model...
# Training 'Account 1' model...
# 'Matched_Name' Accuracy: 0.77
# 'Account 1' Accuracy: 0.81
# Predicted Matched_Name: Uniqlo
# Predicted Account 1: Household:Health,Fitness,Personal

# %% [markdown]
# **Analysis Model:-**
# * The output of the Random Forest model shows the training progress for two different tasks: predicting the Matched_Name and Account 1. The Matched_Name model achieved an accuracy of 77%, indicating that it correctly predicted the matched name in 77% of the cases. This suggests that the model is performing reasonably well but may have some room for improvement, especially in handling edge cases or rare examples. On the other hand, the Account 1 model performed slightly better with an accuracy of 81%, meaning it correctly classified the account in 81% of the cases. This indicates that the Account 1 model is likely handling the classification task more effectively, possibly due to clearer data patterns or more relevant features. However, in both models, there may still be opportunities for fine-tuning or optimizing features to further enhance performance.

# %% [markdown]
# ## Named entity recognition Algorithm :- NER

# %% [markdown]
# * Named Entity Recognition (NER) is a natural language processing technique that identifies and classifies entities in text, such as names of people, organizations, locations, dates, and other specific terms. It helps extract structured information from unstructured text. NER models, often based on machine learning or deep learning algorithms, analyze the context of words to accurately detect entities. This technique is widely used in applications like information retrieval, document classification, and sentiment analysis, where understanding key entities is essential for processing and categorizing data.

# %%
import pandas as pd # use for data manipalution
import re # use for reguler expression
import spacy # use for NER 
from sklearn.model_selection import train_test_split # use for train and test data check
from sklearn.feature_extraction.text import TfidfVectorizer # use for categorical to numerical
from sklearn.ensemble import RandomForestClassifier # import RM model
from sklearn.pipeline import Pipeline # create custome pipline 
from sklearn.metrics import accuracy_score # check the model evaluation

# Load spaCy's pre-trained NER model
nlp = spacy.load("en_core_web_sm")

# Load dataset (replace with actual file)
file_path = "Categorized_Transactions.csv"
data = pd.read_csv(file_path)

# Ensure required columns exist
required_columns = ["Description", "Matched_Name", "Account 1"]
for col in required_columns:
    if col not in data.columns:
        raise ValueError(f"Missing required column: {col} in the dataset")

# Fill missing values
data["Description"] = data["Description"].fillna("Unknown")
data["Matched_Name"] = data["Matched_Name"].fillna("Not Found")
data["Account 1"] = data["Account 1"].fillna("Not Found")

# Clean text (Remove numbers, special characters)
def clean_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    return text.strip()

# Function to extract named entities from the description using spaCy
def extract_entities(text):
    doc = nlp(text)  # Process the text with spaCy's NER model
    entities = []
    for ent in doc.ents:
        entities.append(ent.text)  # Collect the text of each named entity
    return " ".join(entities)  # Combine entities into one string for feature extraction

data["Cleaned_Description"] = data["Description"].apply(clean_text)
data["Extracted_Entities"] = data["Cleaned_Description"].apply(extract_entities)

# Use either the original description or the extracted entities
# Here, we are using the extracted entities as a feature for classification
X_train, X_test, y_train_name, y_test_name = train_test_split(data["Extracted_Entities"], data["Matched_Name"], test_size=0.2, random_state=42)
X_train, X_test, y_train_acc, y_test_acc = train_test_split(data["Extracted_Entities"], data["Account 1"], test_size=0.2, random_state=42)

# Create TF-IDF Vectorizer + Random Forest Pipeline for Matched_Name and Account 1
model_name = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', RandomForestClassifier(n_estimators=100, random_state=42))
])

model_acc = Pipeline([
    ('tfidf', TfidfVectorizer(ngram_range=(1,2))),
    ('clf', RandomForestClassifier(n_estimators=100, random_state=42))
])

# Train models
print("Training 'Matched_Name' model...")
model_name.fit(X_train, y_train_name)

print("Training 'Account 1' model...")
model_acc.fit(X_train, y_train_acc)

# Predict on test set
y_pred_name = model_name.predict(X_test)
y_pred_acc = model_acc.predict(X_test)

# Evaluate accuracy
print(f"'Matched_Name' Accuracy: {accuracy_score(y_test_name, y_pred_name):.2f}")
print(f"'Account 1' Accuracy: {accuracy_score(y_test_acc, y_pred_acc):.2f}")

# Function to predict new descriptions
def classify_transaction(description):
    cleaned_desc = clean_text(description)
    # Extract named entities from the cleaned description using the NER model
    entities = extract_entities(cleaned_desc)
    matched_name_pred = model_name.predict([entities])[0]
    account_pred = model_acc.predict([entities])[0]
    return matched_name_pred, account_pred

# Example Usage
description = "ABC copmany buy the 10 cars"
matched_name, account_category = classify_transaction(description)
print(f"Predicted Matched_Name: {matched_name}")
print(f"Predicted Account 1: {account_category}")
# Out:
# Training 'Matched_Name' model...
# Training 'Account 1' model...
# 'Matched_Name' Accuracy: 0.81
# 'Account 1' Accuracy: 0.89
# Predicted Matched_Name: No Found
# Predicted Account 1: Not Found

# %% [markdown]
# **Analysis Model:-**
# * he output of the NER model shows the training results for two tasks: predicting the Matched_Name and Account 1. The Matched_Name model achieved an accuracy of 81%, indicating that it correctly identified the matched names in 81% of the cases during training. However, the prediction for the Matched_Name task was "No Found," suggesting that, in this instance, the model did not find a match in the given input text or that no relevant entity was detected. On the other hand, the Account 1 model performed better with an accuracy of 89%, meaning it correctly predicted the account category in 89% of the cases. However, the prediction for Account 1 was "Not Found," indicating that the model did not identify a relevant account category in this case. While both models show relatively high accuracy, the "Not Found" and "No Found" predictions suggest that the input data might not contain recognizable entities or the models need further refinement or more context to improve entity detection in specific cases.

# %% [markdown]
# ## LSTM :- Long Short Tearm Memory

# %% [markdown]
# * Long Short-Term Memory (LSTM) is a type of recurrent neural network (RNN) designed to overcome the vanishing gradient problem, allowing it to capture long-term dependencies in sequential data. LSTMs use special units, called memory cells, to maintain information over long sequences by regulating the flow of information through gates (input, forget, and output gates). This ability makes LSTM models highly effective for tasks involving time series data, speech recognition, language modeling, and machine translation. They are particularly useful when the model needs to remember important context from earlier in the sequence to make accurate predictions later on.

# %%
import pandas as pd # use for data manipalution
import numpy as np # use for numrical function
import re # use for reguklar expression
import tensorflow as tf # use tensorflow library for deep lerning
from tensorflow.keras.preprocessing.text import Tokenizer # use for text classification probelm
from tensorflow.keras.preprocessing.sequence import pad_sequences # use for deep learning
from tensorflow.keras.models import Sequential # use sequenction model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout # call LSTM mdoel
from tensorflow.keras.callbacks import EarlyStopping # Use for performance
from sklearn.preprocessing import LabelEncoder # use for categorical to numerical 
from sklearn.model_selection import train_test_split # use for tarin and test data
from sklearn.metrics import classification_report # use for model evaluation

# Load dataset
file_path = "Categorized_Transactions.csv"
data = pd.read_csv(file_path)

# Ensure required columns exist
required_columns = ["Description", "Matched_Name", "Account 1"]
for col in required_columns:
    if col not in data.columns:
        raise ValueError(f"Missing required column: {col} in the dataset")

# Fill missing values
data["Description"] = data["Description"].fillna("Unknown")
data["Matched_Name"] = data["Matched_Name"].fillna("Not Found")
data["Account 1"] = data["Account 1"].fillna("Not Found")

# Clean text function
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove special characters
    return text.strip()

data["Cleaned_Description"] = data["Description"].apply(clean_text)

# Tokenize text with OOV handling
MAX_VOCAB_SIZE = 5000  # Limit vocabulary size for better generalization
OOV_TOKEN = "<OOV>"  # Token for out-of-vocabulary words

tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token=OOV_TOKEN)
tokenizer.fit_on_texts(data["Cleaned_Description"])

# Convert text to sequences
X = tokenizer.texts_to_sequences(data["Cleaned_Description"])
X = pad_sequences(X, padding='post')

# Encode target variables
label_enc_name = LabelEncoder()
data["Matched_Name_Encoded"] = label_enc_name.fit_transform(data["Matched_Name"])

label_enc_acc = LabelEncoder()
data["Account_Encoded"] = label_enc_acc.fit_transform(data["Account 1"])

# Train-test split
X_train, X_test, y_train_name, y_test_name = train_test_split(X, data["Matched_Name_Encoded"], test_size=0.2, random_state=42)
X_train, X_test, y_train_acc, y_test_acc = train_test_split(X, data["Account_Encoded"], test_size=0.2, random_state=42)

# LSTM Model with pre-trained FastText embeddings (enhanced architecture)
def build_lstm_model(output_dim, vocab_size, input_length):
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=50, input_length=input_length, mask_zero=True),
        LSTM(200, return_sequences=False, dropout=0.2, recurrent_dropout=0.2),
        Dense(50, activation='relu'),
        Dense(output_dim, activation='softmax')  # Softmax for multi-class classification
    ])
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Build models
vocab_size = min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE)
input_length = X.shape[1]

model_name = build_lstm_model(len(label_enc_name.classes_), vocab_size, input_length)
model_acc = build_lstm_model(len(label_enc_acc.classes_), vocab_size, input_length)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train 'Matched_Name' model
print("Training 'Matched_Name' model...")
model_name.fit(X_train, y_train_name, epochs=100, batch_size=32, validation_data=(X_test, y_test_name), callbacks=[early_stopping])

# Train 'Account 1' model
print("Training 'Account 1' model...")
model_acc.fit(X_train, y_train_acc, epochs=100, batch_size=32, validation_data=(X_test, y_test_acc), callbacks=[early_stopping])

# Save models
model_name.save("lstm_matched_name.h5")
model_acc.save("lstm_account.h5")

print("Models saved successfully!")

# Prediction Function with OOV Handling
def classify_transaction(description, threshold=50, top_n=3):
    cleaned_desc = clean_text(description)
    seq = tokenizer.texts_to_sequences([cleaned_desc])
    padded_seq = pad_sequences(seq, maxlen=X.shape[1])

    # Predict categories
    pred_name = model_name.predict(padded_seq)[0]
    pred_acc = model_acc.predict(padded_seq)[0]

    # Get top N predictions
    top_name_indices = np.argsort(pred_name)[-top_n:][::-1]
    top_acc_indices = np.argsort(pred_acc)[-top_n:][::-1]

    top_names = [(label_enc_name.inverse_transform([idx])[0], pred_name[idx] * 100) for idx in top_name_indices]
    top_accounts = [(label_enc_acc.inverse_transform([idx])[0], pred_acc[idx] * 100) for idx in top_acc_indices]

    # If top prediction confidence is below threshold, return "Not Found"
    best_matched_name, best_matched_conf = top_names[0]
    if best_matched_conf < threshold:
        best_matched_name = "Not Found"

    best_account, best_account_conf = top_accounts[0]
    if best_account_conf < threshold:
        best_account = "Not Found"

    return best_matched_name, best_matched_conf, best_account, best_account_conf, top_names, top_accounts

# Example Usage
description = "Visa -Tonkotsuya Carlingford AU#5977439"
matched_name, matched_name_conf, account_category, account_conf, top_names, top_accounts = classify_transaction(description)

# Print results
print(f"Predicted Matched_Name: {matched_name} ({matched_name_conf:.2f}%)")
print(f"Predicted Account 1: {account_category} ({account_conf:.2f}%)")

print("\nTop Matched Names:")
for name, conf in top_names:
    print(f"- {name} ({conf:.2f}%)")

print("\nTop Account Types:")
for acc, conf in top_accounts:
    print(f"- {acc} ({conf:.2f}%)")

# Evaluate models
y_pred_name = model_name.predict(X_test)
y_pred_acc = model_acc.predict(X_test)

# Convert predictions back to labels
y_pred_name_labels = np.argmax(y_pred_name, axis=1)
y_pred_acc_labels = np.argmax(y_pred_acc, axis=1)

print("\nClassification Report for 'Matched_Name':")
print(classification_report(y_test_name, y_pred_name_labels))

print("\nClassification Report for 'Account 1':")
print(classification_report(y_test_acc, y_pred_acc_labels))
# Out:
# Training 'Matched_Name' model...
# Epoch 1/100
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.3732 - loss: 3.4484 - val_accuracy: 0.3973 - val_loss: 3.0392
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.3436 - loss: 2.7560 - val_accuracy: 0.3973 - val_loss: 2.0517
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.3432 - loss: 2.1865 - val_accuracy: 0.6301 - val_loss: 1.8901
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6537 - loss: 1.8368 - val_accuracy: 0.6301 - val_loss: 1.6999
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6092 - loss: 1.7218 - val_accuracy: 0.6575 - val_loss: 1.5537
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.6886 - loss: 1.4087 - val_accuracy: 0.6849 - val_loss: 1.4237
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6700 - loss: 1.3590 - val_accuracy: 0.6849 - val_loss: 1.3051
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.6983 - loss: 1.0402 - val_accuracy: 0.6849 - val_loss: 1.2633
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7057 - loss: 0.9849 - val_accuracy: 0.6849 - val_loss: 1.1931
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7419 - loss: 0.8609 - val_accuracy: 0.6849 - val_loss: 1.1896
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.6904 - loss: 0.8914 - val_accuracy: 0.6849 - val_loss: 1.1989
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.7600 - loss: 0.6231 - val_accuracy: 0.7397 - val_loss: 1.1751
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7986 - loss: 0.6595 - val_accuracy: 0.7945 - val_loss: 1.2389
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8289 - loss: 0.6291 - val_accuracy: 0.7808 - val_loss: 1.1458
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.8778 - loss: 0.5096 - val_accuracy: 0.7945 - val_loss: 1.1873
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8797 - loss: 0.4585 - val_accuracy: 0.8082 - val_loss: 1.1740
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8948 - loss: 0.3697 - val_accuracy: 0.8082 - val_loss: 1.1280
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9004 - loss: 0.3611 - val_accuracy: 0.8082 - val_loss: 1.1248
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8923 - loss: 0.3689 - val_accuracy: 0.8082 - val_loss: 1.1948
# Epoch 20/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9209 - loss: 0.2792 - val_accuracy: 0.8356 - val_loss: 1.1664
# Epoch 21/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9255 - loss: 0.2841 - val_accuracy: 0.8356 - val_loss: 1.1854
# Epoch 22/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.8837 - loss: 0.3856 - val_accuracy: 0.8356 - val_loss: 1.2058
# Epoch 23/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9195 - loss: 0.2887 - val_accuracy: 0.8356 - val_loss: 1.1970
# Training 'Account 1' model...
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 91ms/step - accuracy: 0.5084 - loss: 2.3520 - val_accuracy: 0.7945 - val_loss: 1.9497
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.7467 - loss: 1.6740 - val_accuracy: 0.7945 - val_loss: 1.1069
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7577 - loss: 1.1980 - val_accuracy: 0.7945 - val_loss: 0.9470
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7128 - loss: 1.1111 - val_accuracy: 0.7945 - val_loss: 0.8044
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7344 - loss: 0.9372 - val_accuracy: 0.7945 - val_loss: 0.7338
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7478 - loss: 0.7555 - val_accuracy: 0.7945 - val_loss: 0.6800
# Epoch 7/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.7446 - loss: 0.6927 - val_accuracy: 0.7945 - val_loss: 0.6200
# Epoch 8/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.7766 - loss: 0.5941 - val_accuracy: 0.7945 - val_loss: 0.5802
# Epoch 9/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.7954 - loss: 0.5334 - val_accuracy: 0.7945 - val_loss: 0.5404
# Epoch 10/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7721 - loss: 0.5546 - val_accuracy: 0.7945 - val_loss: 0.5191
# Epoch 11/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7778 - loss: 0.4642 - val_accuracy: 0.9041 - val_loss: 0.4562
# Epoch 12/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.9398 - loss: 0.2806 - val_accuracy: 0.9315 - val_loss: 0.4004
# Epoch 13/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9615 - loss: 0.1819 - val_accuracy: 0.9315 - val_loss: 0.4169
# Epoch 14/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9598 - loss: 0.1362 - val_accuracy: 0.9315 - val_loss: 0.3948
# Epoch 15/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9631 - loss: 0.1265 - val_accuracy: 0.9452 - val_loss: 0.4612
# Epoch 16/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9664 - loss: 0.0994 - val_accuracy: 0.9315 - val_loss: 0.4233
# Epoch 17/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9666 - loss: 0.0885 - val_accuracy: 0.9315 - val_loss: 0.4480
# Epoch 18/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9522 - loss: 0.1177 - val_accuracy: 0.9452 - val_loss: 0.5364
# Epoch 19/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9699 - loss: 0.0982 - val_accuracy: 0.9315 - val_loss: 0.5230
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# Predicted Matched_Name: Not Found (4.23%)
# Predicted Account 1: Not Found (12.62%)
#
# Top Matched Names:
# - Amazon (4.23%)
# - No Found (4.17%)
# - Coles (3.88%)
#
# Top Account Types:
# - Office Supplies (12.62%)
# - Meals and Entertainment (10.36%)
# - Household:Health,Fitness,Personal (10.08%)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
#
# Classification Report for 'Matched_Name':
#               precision    recall  f1-score   support
#
#            2       0.55      1.00      0.71         6
#            3       1.00      0.93      0.96        29
#            4       0.00      0.00      0.00         1
#            7       0.80      1.00      0.89         4
#            8       0.00      0.00      0.00         1
#            9       0.00      0.00      0.00         0
#           14       0.00      0.00      0.00         1
#           15       0.00      0.00      0.00         1
#           19       0.00      0.00      0.00         2
#           20       0.81      0.96      0.88        23
#           25       0.00      0.00      0.00         1
#           29       0.00      0.00      0.00         1
#           32       0.00      0.00      0.00         3
#
#     accuracy                           0.81        73
#    macro avg       0.24      0.30      0.26        73
# weighted avg       0.74      0.81      0.77        73
#
#
# Classification Report for 'Account 1':
#               precision    recall  f1-score   support
#
#            3       0.83      1.00      0.91         5
#            4       0.00      0.00      0.00         3
#            7       0.93      0.98      0.96        58
#            8       1.00      1.00      1.00         6
#           10       0.00      0.00      0.00         1
#
#     accuracy                           0.93        73
#    macro avg       0.55      0.60      0.57        73
# weighted avg       0.88      0.93      0.91        73
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ## Random Data Genrate

# %% [markdown]
# * To generate random data, we can create a dataset with synthetic values that resemble real-world data but aren't based on any actual sources. For instance, a dataset might include randomly generated values such as names, ages, cities, and product prices. Using libraries like NumPy or Pandas in Python, we can generate random numbers, select values from predefined lists, and assign random dates or categorical labels. For example, a random dataset might consist of 100 rows, where each row contains a name (e.g., "John Doe"), an age (e.g., 25), a city (e.g., "New York"), and a price (e.g., $150). Random data generation is commonly used for testing, simulating scenarios, and building models when real data isn't available or when testing the performance of algorithms on synthetic input.

# %%
import csv
import random

# Define a function to generate descriptions based on account and match name
def generate_description(match_name, account):
    description_templates = [
        f"{match_name} uses {account} to manage its operations efficiently.",
        f"The {account} account is a vital part of {match_name}'s financial strategy.",
        f"{match_name} utilizes {account} for handling its financial transactions and investments.",
        f"{match_name} processes payments through {account} for its ongoing projects.",
        f"The {account} account reflects payments and expenditures related to {match_name}'s services.",
        f"{match_name} settles all vendor payments through {account}, ensuring timely transaction processing.",
        f"By leveraging {account}, {match_name} ensures smooth cash flow for its business operations."
    ]
    
    return random.choice(description_templates)

# Define a list of match names and accounts
match_names = ["SOUNDHOUND AI INC", "Nextera Energy", "Vanguard", "Superprof", "Haaretz", "Myer-AUD", "BANNERMAN ENERGY LTD", "Farha Roofing", "QuickBooks Payments"]
accounts = ["AAdvantage Aviator", "Accounts Payable", "ANZ_Land Loan Offset_8143", "Rent Income", "Repair & Maintenance - AUD", "Repairs", "Appliances", "Door Lock & Keys", "Door Lock, Key & Materials"]

# Generate 1500 rows of data
data = [["Match Name", "Account", "Description"]]  # Header row

for _ in range(1500):
    match_name = random.choice(match_names)
    account = random.choice(accounts)
    description = generate_description(match_name, account)
    data.append([match_name, account, description])

# Specify the CSV filename
filename = "match_accounts_descriptions_1500.csv"

# Writing to CSV
with open(filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerows(data)

print(f"CSV file '{filename}' has been created with 1500 rows.")
# Out:
# CSV file 'match_accounts_descriptions_1500.csv' has been created with 1500 rows.

# %%
g1 = pd.read_csv("match_accounts_descriptions_1500.csv") # load the CSV File
g1
# Out:
#                Match Name                     Account  \
# 0     QuickBooks Payments                 Rent Income
# 1          Nextera Energy            Door Lock & Keys
# 2       SOUNDHOUND AI INC                     Repairs
# 3                Myer-AUD          AAdvantage Aviator
# 4                Myer-AUD  Repair & Maintenance - AUD
# ...                   ...                         ...
# 1495             Vanguard                  Appliances
# 1496             Myer-AUD  Door Lock, Key & Materials
# 1497            Superprof                     Repairs
# 1498            Superprof          AAdvantage Aviator
# 1499  QuickBooks Payments  Door Lock, Key & Materials
#
#                                             Description
# 0     QuickBooks Payments utilizes Rent Income for h...
# 1     By leveraging Door Lock & Keys, Nextera Energy...
# 2     By leveraging Repairs, SOUNDHOUND AI INC ensur...
# 3     Myer-AUD uses AAdvantage Aviator to manage its...
# 4     The Repair & Maintenance - AUD account reflect...
# ...                                                 ...
# 1495  Vanguard uses Appliances to manage its operati...
# 1496  By leveraging Door Lock, Key & Materials, Myer...
# 1497  The Repairs account reflects payments and expe...
# 1498  The AAdvantage Aviator account is a vital part...
# 1499  QuickBooks Payments processes payments through...
#
# [1500 rows x 3 columns]

# %%
g2 = g1.rename(columns={"Match Name":"Matched_Name","Account":"Account 1"}) # use for rename the column anme
g2
# Out:
#              Matched_Name                   Account 1  \
# 0     QuickBooks Payments                 Rent Income
# 1          Nextera Energy            Door Lock & Keys
# 2       SOUNDHOUND AI INC                     Repairs
# 3                Myer-AUD          AAdvantage Aviator
# 4                Myer-AUD  Repair & Maintenance - AUD
# ...                   ...                         ...
# 1495             Vanguard                  Appliances
# 1496             Myer-AUD  Door Lock, Key & Materials
# 1497            Superprof                     Repairs
# 1498            Superprof          AAdvantage Aviator
# 1499  QuickBooks Payments  Door Lock, Key & Materials
#
#                                             Description
# 0     QuickBooks Payments utilizes Rent Income for h...
# 1     By leveraging Door Lock & Keys, Nextera Energy...
# 2     By leveraging Repairs, SOUNDHOUND AI INC ensur...
# 3     Myer-AUD uses AAdvantage Aviator to manage its...
# 4     The Repair & Maintenance - AUD account reflect...
# ...                                                 ...
# 1495  Vanguard uses Appliances to manage its operati...
# 1496  By leveraging Door Lock, Key & Materials, Myer...
# 1497  The Repairs account reflects payments and expe...
# 1498  The AAdvantage Aviator account is a vital part...
# 1499  QuickBooks Payments processes payments through...
#
# [1500 rows x 3 columns]

# %%
df4a
# Out:
#       Amount                        Bank  \
# 0     290.33        Chase Property #0184
# 1    1000.00  ANZ_Construction Loan_6823
# 2     137.35      American Express #2003
# 3      66.14      American Express #2003
# 4      73.02      American Express #2003
# ..       ...                         ...
# 357     7.05         Bank Australia#0902
# 358     7.06         Bank Australia#0902
# 359     7.24         Bank Australia#0902
# 360     7.50         Bank Australia#0902
# 361   496.15         Bank Australia#0902
#
#                                            Description        Date     Type  \
# 0        AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428  2024-06-21   Income
# 1    ANZ M-BANKING FUNDS TFER                TRANSF...  2024-11-03  Expense
# 2                  UNIQLO USA LLC NEW YORK NY XXXX2003  2024-11-18  Expense
# 3          LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003  2024-11-18  Expense
# 4    Interest Charge on Pay Over Time Purchases XXX...  2024-11-25  Expense
# ..                                                 ...         ...      ...
# 357  Visa Live Group/8/1 Progress Aeastwood AU#5977...  2024-02-27  Expense
# 358  Visa Lees Farm Eastwood AU#5977439 (Ref.022800...  2024-02-28  Expense
# 359  Visa -Tonkotsuya Carlingford AU#5977439 (Ref.0...  2024-02-02  Expense
# 360  Visa Abdulaziz Radi Shellharbour AU#5977439 (R...  2024-02-29  Expense
# 361  Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.0...  2024-02-11  Expense
#
#     Matched_Name                          Account 1
# 0         AirBnB                      Rental Income
# 1       No Found                          Not Found
# 2         Uniqlo  Household:Health,Fitness,Personal
# 3           LIDS  Household:Health,Fitness,Personal
# 4       No Found                          Not Found
# ..           ...                                ...
# 357        Apple                          Not Found
# 358        Apple                          Not Found
# 359   Tonkotsuya            Meals and Entertainment
# 360        Apple                          Not Found
# 361        Coles                Household:Groceries
#
# [362 rows x 7 columns]

# %%
dfs = pd.concat([df4,g2],axis=0) # use for concate the two variable
dfs
# Out:
#        Amount                        Bank  \
# 0      290.33        Chase Property #0184
# 1     1000.00  ANZ_Construction Loan_6823
# 2      137.35      American Express #2003
# 3       66.14      American Express #2003
# 4       73.02      American Express #2003
# ...       ...                         ...
# 1495      NaN                         NaN
# 1496      NaN                         NaN
# 1497      NaN                         NaN
# 1498      NaN                         NaN
# 1499      NaN                         NaN
#
#                                             Description        Date     Type  \
# 0         AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428  2024-06-21   Income
# 1     ANZ M-BANKING FUNDS TFER                TRANSF...  2024-11-03  Expense
# 2                   UNIQLO USA LLC NEW YORK NY XXXX2003  2024-11-18  Expense
# 3           LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003  2024-11-18  Expense
# 4     Interest Charge on Pay Over Time Purchases XXX...  2024-11-25  Expense
# ...                                                 ...         ...      ...
# 1495  Vanguard uses Appliances to manage its operati...         NaN      NaN
# 1496  By leveraging Door Lock, Key & Materials, Myer...         NaN      NaN
# 1497  The Repairs account reflects payments and expe...         NaN      NaN
# 1498  The AAdvantage Aviator account is a vital part...         NaN      NaN
# 1499  QuickBooks Payments processes payments through...         NaN      NaN
#
#              Matched_Name                          Account 1
# 0                  AirBnB                      Rental Income
# 1                No Found                          Not Found
# 2                  Uniqlo  Household:Health,Fitness,Personal
# 3                    LIDS  Household:Health,Fitness,Personal
# 4                No Found                          Not Found
# ...                   ...                                ...
# 1495             Vanguard                         Appliances
# 1496             Myer-AUD         Door Lock, Key & Materials
# 1497            Superprof                            Repairs
# 1498            Superprof                 AAdvantage Aviator
# 1499  QuickBooks Payments         Door Lock, Key & Materials
#
# [1862 rows x 7 columns]

# %%
dfs.columns # use for check the column name
# Out:
# Index(['Amount', 'Bank', 'Description', 'Date', 'Type', 'Matched_Name',
#        'Account 1'],
#       dtype='object')

# %%
dfd = dfs.drop(['Amount', 'Bank', 'Date', 'Type'],axis=1) #drop the invalid columns
dfd.iloc[1496][0]
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_10120\2718525868.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dfd.iloc[1496][0]
# "The Repair & Maintenance - AUD account is a vital part of Vanguard's financial strategy."

# %%
cc = dfd.to_csv("ABC.csv") # data convert to csv file
cc

# %%
import pandas as pd # use for data manipalution
import numpy as np # use for numerical function
import re # use for regular expression
from sklearn.model_selection import train_test_split # use for train and test data
from sklearn.preprocessing import LabelEncoder # use for categoorical to numerical data
from tensorflow.keras.preprocessing.text import Tokenizer # use for word vise work
from tensorflow.keras.preprocessing.sequence import pad_sequences # use for data sequence vise work
from tensorflow.keras.models import Sequential, load_model # Import load_model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional # use lSTM model 
from tensorflow.keras.callbacks import EarlyStopping # reduce the overfiting problem solve
from tensorflow.keras.regularizers import l1_l2 # call the L1 or L2 model
from sklearn.metrics import classification_report # use for calssification probelm

# Load dataset
file_path = "ABC.csv"  # Replace with your actual file path
data = pd.read_csv(file_path)

# Data cleaning and preprocessing
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove special characters
    return text.strip()

data["Cleaned_Description"] = data["Description"].apply(clean_text)

# Tokenizer (increased vocabulary size)
MAX_VOCAB_SIZE = 10000
OOV_TOKEN = "<OOV>"
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token=OOV_TOKEN)
tokenizer.fit_on_texts(data["Cleaned_Description"])

# Label encoding
label_enc_name = LabelEncoder()
data["Matched_Name_Encoded"] = label_enc_name.fit_transform(data["Matched_Name"])

label_enc_acc = LabelEncoder()
data["Account_Encoded"] = label_enc_acc.fit_transform(data["Account 1"])

# Convert text to sequences
X = tokenizer.texts_to_sequences(data["Cleaned_Description"])
X = pad_sequences(X, padding='post', truncating='post')

# Train-test split
X_train, X_test, y_train_name, y_test_name = train_test_split(X, data["Matched_Name_Encoded"], test_size=0.2, random_state=42)
X_train, X_test, y_train_acc, y_test_acc = train_test_split(X, data["Account_Encoded"], test_size=0.2, random_state=42)

# Enhanced LSTM Model
def build_lstm_model(output_dim, vocab_size, input_length):
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=100, input_length=input_length, mask_zero=True),
        Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3)),
        Bidirectional(LSTM(64, dropout=0.3, recurrent_dropout=0.3)),
        Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)),
        Dropout(0.3),
        Dense(output_dim, activation='softmax')
    ])
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Build models
vocab_size = min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE)
input_length = X.shape[1]

model_name = build_lstm_model(len(label_enc_name.classes_), vocab_size, input_length)
model_acc = build_lstm_model(len(label_enc_acc.classes_), vocab_size, input_length)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train models
print("Training 'Matched_Name' model...")
model_name.fit(X_train, y_train_name, epochs=50, batch_size=32, validation_data=(X_test, y_test_name), callbacks=[early_stopping])

print("Training 'Account 1' model...")
model_acc.fit(X_train, y_train_acc, epochs=50, batch_size=32, validation_data=(X_test, y_test_acc), callbacks=[early_stopping])

# Save models
model_name.save("lstm_matched_name.h5")
model_acc.save("lstm_account.h5")

print("Models saved successfully!")


# --- Prediction Code ---

# Load models (in a separate script or after training)
model_name = load_model("lstm_matched_name.h5")
model_acc = load_model("lstm_account.h5")

# ... (Load data, clean_text function, tokenizer, label encoders - same as above)

# Get input length (from loaded model)
input_length = model_name.layers[0].input.shape[1]

# Prediction Function
def classify_transaction(description, threshold=50, top_n=3):
    cleaned_desc = clean_text(description)
    seq = tokenizer.texts_to_sequences([cleaned_desc])
    padded_seq = pad_sequences(seq, maxlen=input_length, padding='post')

    pred_name = model_name.predict(padded_seq)[0]
    pred_acc = model_acc.predict(padded_seq)[0]

    top_name_indices = np.argsort(pred_name)[-top_n:][::-1]
    top_acc_indices = np.argsort(pred_acc)[-top_n:][::-1]

    top_names = [(label_enc_name.inverse_transform([idx])[0], pred_name[idx] * 100) for idx in top_name_indices]
    top_accounts = [(label_enc_acc.inverse_transform([idx])[0], pred_acc[idx] * 100) for idx in top_acc_indices]

    best_matched_name, best_matched_conf = top_names[0]
    if best_matched_conf < threshold:
        best_matched_name = "Not Found"

    best_account, best_account_conf = top_accounts[0]
    if best_account_conf < threshold:
        best_account = "Not Found"

    return best_matched_name, best_matched_conf, best_account, best_account_conf, top_names, top_accounts


# Example Usage
description = "Payments related to Staff Salaries are processed through Vortex Technologies to maintain workforce satisfaction."
matched_name, matched_name_conf, account_category, account_conf, top_names, top_accounts = classify_transaction(description)

print(f"Predicted Matched_Name: {matched_name} ({matched_name_conf:.2f}%)")
print(f"Predicted Account 1: {account_category} ({account_conf:.2f}%)")

print("\nTop Matched Names:")
for name, conf in top_names:
    print(f"- {name} ({conf:.2f}%)")

print("\nTop Account Types:")
for acc, conf in top_accounts:
    print(f"- {acc} ({conf:.2f}%)")

# Evaluate models (on test set - after training)
y_pred_name = model_name.predict(X_test)
y_pred_acc = model_acc.predict(X_test)

y_pred_name_labels = np.argmax(y_pred_name, axis=1)
y_pred_acc_labels = np.argmax(y_pred_acc, axis=1)

print("\nClassification Report for 'Matched_Name':")
print(classification_report(y_test_name, y_pred_name_labels))

print("\nClassification Report for 'Account 1':")
print(classification_report(y_test_acc, y_pred_acc_labels))
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Training 'Matched_Name' model...
# Epoch 1/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 45s 260ms/step - accuracy: 0.1047 - loss: 3.3880 - val_accuracy: 0.1635 - val_loss: 2.4537
# Epoch 2/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.2597 - loss: 2.2951 - val_accuracy: 0.5737 - val_loss: 1.3380
# Epoch 3/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.6212 - loss: 1.1944 - val_accuracy: 0.9196 - val_loss: 0.5250
# Epoch 4/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 191ms/step - accuracy: 0.8568 - loss: 0.5708 - val_accuracy: 0.9598 - val_loss: 0.3037
# Epoch 5/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 187ms/step - accuracy: 0.9419 - loss: 0.2956 - val_accuracy: 0.9437 - val_loss: 0.3318
# Epoch 6/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9269 - loss: 0.2573 - val_accuracy: 0.9625 - val_loss: 0.2828
# Epoch 7/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 177ms/step - accuracy: 0.9595 - loss: 0.2017 - val_accuracy: 0.9651 - val_loss: 0.2743
# Epoch 8/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 180ms/step - accuracy: 0.9705 - loss: 0.1413 - val_accuracy: 0.9651 - val_loss: 0.2894
# Epoch 9/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9635 - loss: 0.1642 - val_accuracy: 0.9678 - val_loss: 0.2826
# Epoch 10/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.9655 - loss: 0.1393 - val_accuracy: 0.9678 - val_loss: 0.3128
# Epoch 11/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 180ms/step - accuracy: 0.9717 - loss: 0.1254 - val_accuracy: 0.9678 - val_loss: 0.3155
# Epoch 12/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 179ms/step - accuracy: 0.9689 - loss: 0.1278 - val_accuracy: 0.9678 - val_loss: 0.2653
# Epoch 13/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.9708 - loss: 0.1045 - val_accuracy: 0.9678 - val_loss: 0.2936
# Epoch 14/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9680 - loss: 0.1235 - val_accuracy: 0.9678 - val_loss: 0.3046
# Epoch 15/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 182ms/step - accuracy: 0.9626 - loss: 0.1377 - val_accuracy: 0.9651 - val_loss: 0.3394
# Epoch 16/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.9640 - loss: 0.1511 - val_accuracy: 0.9651 - val_loss: 0.3044
# Epoch 17/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 183ms/step - accuracy: 0.9829 - loss: 0.0757 - val_accuracy: 0.9705 - val_loss: 0.3284
# Epoch 18/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 192ms/step - accuracy: 0.9763 - loss: 0.0954 - val_accuracy: 0.9732 - val_loss: 0.3348
# Epoch 19/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s
50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.9988 - loss: 0.0183 - val_accuracy: 0.9893 - val_loss: 0.1677
# Epoch 25/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 175ms/step - accuracy: 0.9969 - loss: 0.0155 - val_accuracy: 0.9893 - val_loss: 0.1721
# Epoch 26/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 174ms/step - accuracy: 0.9982 - loss: 0.0167 - val_accuracy: 0.9812 - val_loss: 0.1541
# Epoch 27/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.9991 - loss: 0.0161 - val_accuracy: 0.9866 - val_loss: 0.1585
# Epoch 28/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 178ms/step - accuracy: 0.9960 - loss: 0.0194 - val_accuracy: 0.9866 - val_loss: 0.1618
# Epoch 29/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 181ms/step - accuracy: 0.9997 - loss: 0.0144 - val_accuracy: 0.9866 - val_loss: 0.1642
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved successfully!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Matched_Name: Nextera Energy (96.39%)
# Predicted Account 1: Appliances (99.25%)
#
# Top Matched Names:
# - Nextera Energy (96.39%)
# - Myer-AUD (1.86%)
# - Haaretz (0.82%)
#
# Top Account Types:
# - Appliances (99.25%)
# - Not Found (0.47%)
# - Dues and Subscriptions (0.15%)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step
#
# Classification Report for 'Matched_Name':
#               precision    recall  f1-score   support
#
#            2       1.00      1.00      1.00         7
#            3       0.81      1.00      0.89        29
#            4       1.00      1.00      1.00        28
#            7       0.00      0.00      0.00         1
#            8       0.91      1.00      0.95        10
#           12       0.00      0.00      0.00         1
#           13       1.00      1.00      1.00        30
#           15       1.00      1.00      1.00        39
#           17       0.00      0.00      0.00         1
#           22       0.00      0.00      0.00         2
#           23       1.00      1.00      1.00        34
#           24       1.00      1.00      1.00        35
#           25       0.80      0.94      0.86        17
#           27       0.00      0.00      0.00         1
#           28       1.00      1.00      1.00        32
#           30       0.00      0.00      0.00         1
#           31       1.00      1.00      1.00        30
#           32       0.00      0.00      0.00         2
#           33       1.00      1.00      1.00        40
#           39       1.00      1.00      1.00        31
#           41       0.00      0.00      0.00         2
#
#     accuracy                           0.97       373
#    macro avg       0.60      0.62      0.61       373
# weighted avg       0.94      0.97      0.95       373
#
#
# Classification Report for 'Account 1':
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       1.00      1.00      1.00        34
#            2       1.00      1.00      1.00        35
#            3       1.00      1.00      1.00        35
#            5       1.00      1.00      1.00        32
#            6       1.00      1.00      1.00        44
#            8       0.00      0.00      0.00         1
#            9       1.00      1.00      1.00        12
#           10       0.00      0.00      0.00         2
#           11       0.00      0.00      0.00         1
#           13       0.93      1.00      0.96        51
#           14       1.00      1.00      1.00         7
#           15       1.00      1.00      1.00        33
#           17       1.00      1.00      1.00        35
#           18       1.00      1.00      1.00        22
#
#     accuracy                           0.99       373
#    macro avg       0.80      0.80      0.80       373
# weighted avg       0.98      0.99      0.98       373
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **Analysis Model:-**
# * The model's performance shows strong results, with high prediction accuracies for both Matched_Name and Account 1. The Matched_Name prediction for "Nextera Energy" is highly accurate at 96.39%, indicating that the model correctly identified the entity in most cases. Other potential matches include "Myer-AUD" (1.86%) and "Haaretz" (0.82%), though these have much lower probabilities, suggesting they are less likely to be correct. For Account 1, the model predicted "Appliances" with an impressive accuracy of 99.25%, demonstrating its strong capability in classifying account types. The other top predictions include "Not Found" (0.47%) and "Dues and Subscriptions" (0.15%), which show a very low likelihood of being correct. Overall, the model performs excellently in identifying and classifying the correct entities and account types, with very high confidence in its predictions. However, the low-probability alternatives indicate that there may still be edge cases where the model could benefit from further training or data enhancement.

# %% [markdown]
# # Convert output JSON formate

# %%
import pandas as pd # use for data manipalution
import numpy as np # use for numerical function
import re # use for regular expression
from sklearn.model_selection import train_test_split # use for train and test data
from sklearn.preprocessing import LabelEncoder # use for categoorical to numerical data
from tensorflow.keras.preprocessing.text import Tokenizer # use for word vise work
from tensorflow.keras.preprocessing.sequence import pad_sequences # use for data sequence vise work
from tensorflow.keras.models import Sequential, load_model # Import load_model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional # use lSTM model 
from tensorflow.keras.callbacks import EarlyStopping # reduce the overfiting problem solve
from tensorflow.keras.regularizers import l1_l2 # call the L1 or L2 model
from sklearn.metrics import classification_report # use for calssification probelm
import json # use for output convert json form data

# Load dataset
file_path = "ABC.csv"  # Replace with your actual file path
data = pd.read_csv(file_path)

# Data cleaning and preprocessing
def clean_text(text):
    text = text.lower()
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[^\w\s]', '', text)  # Remove special characters
    return text.strip()

data["Cleaned_Description"] = data["Description"].apply(clean_text)

# Tokenizer
MAX_VOCAB_SIZE = 10000
OOV_TOKEN = "<OOV>"
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token=OOV_TOKEN)
tokenizer.fit_on_texts(data["Cleaned_Description"])

# Label encoding
label_enc_name = LabelEncoder()
data["Matched_Name_Encoded"] = label_enc_name.fit_transform(data["Matched_Name"])

label_enc_acc = LabelEncoder()
data["Account_Encoded"] = label_enc_acc.fit_transform(data["Account 1"])

# Convert text to sequences
X = tokenizer.texts_to_sequences(data["Cleaned_Description"])
X = pad_sequences(X, padding='post', truncating='post')

# Train-test split
X_train, X_test, y_train_name, y_test_name = train_test_split(X, data["Matched_Name_Encoded"], test_size=0.2, random_state=42)
X_train, X_test, y_train_acc, y_test_acc = train_test_split(X, data["Account_Encoded"], test_size=0.2, random_state=42)

# Enhanced LSTM Model
def build_lstm_model(output_dim, vocab_size, input_length):
    model = Sequential([
        Embedding(input_dim=vocab_size, output_dim=100, input_length=input_length, mask_zero=True),
        Bidirectional(LSTM(128, return_sequences=True, dropout=0.3, recurrent_dropout=0.3)),
        Bidirectional(LSTM(64, dropout=0.3, recurrent_dropout=0.3)),
        Dense(64, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-5)),
        Dropout(0.3),
        Dense(output_dim, activation='softmax')
    ])
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Build models
vocab_size = min(len(tokenizer.word_index) + 1, MAX_VOCAB_SIZE)
input_length = X.shape[1]

model_name = build_lstm_model(len(label_enc_name.classes_), vocab_size, input_length)
model_acc = build_lstm_model(len(label_enc_acc.classes_), vocab_size, input_length)

# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train models
print("Training 'Matched_Name' model...")
model_name.fit(X_train, y_train_name, epochs=50, batch_size=32, validation_data=(X_test, y_test_name), callbacks=[early_stopping])

print("Training 'Account 1' model...")
model_acc.fit(X_train, y_train_acc, epochs=50, batch_size=32, validation_data=(X_test, y_test_acc), callbacks=[early_stopping])

# Save models
model_name.save("lstm_matched_name.h5")
model_acc.save("lstm_account.h5")

print("Models saved successfully!")


# --- Prediction Code ---

# Load models 
model_name = load_model("lstm_matched_name.h5")
model_acc = load_model("lstm_account.h5")

# Get input length (from loaded model)
input_length = model_name.layers[0].input.shape[1]


# Prediction Function (modified for JSON output)
def classify_transaction(description, threshold=50):
    cleaned_desc = clean_text(description)
    seq = tokenizer.texts_to_sequences([cleaned_desc])
    padded_seq = pad_sequences(seq, maxlen=input_length, padding='post')

    pred_name = model_name.predict(padded_seq)[0]
    pred_acc = model_acc.predict(padded_seq)[0]

    best_name_index = np.argmax(pred_name)
    best_acc_index = np.argmax(pred_acc)

    best_matched_name = label_enc_name.inverse_transform([best_name_index])[0] if pred_name.size > 0 else "Not Found"
    best_account = label_enc_acc.inverse_transform([best_acc_index])[0] if pred_acc.size > 0 else "Not Found"

    best_matched_conf = pred_name[best_name_index] * 100 if pred_name.size > 0 else 0.0
    best_account_conf = pred_acc[best_acc_index] * 100 if pred_acc.size > 0 else 0.0

    if best_matched_conf < threshold:
        best_matched_name = "Not Found"

    if best_account_conf < threshold:
        best_account = "Not Found"

    results = {
        "description": description,
        "predicted_matched_name": f"{best_matched_name} ({best_matched_conf:.2f}%)",
        "predicted_account": f"{best_account} ({best_account_conf:.2f}%)",
    }

    return results


# Example Usage and JSON Output
description = "TechCorp uses Electricity Payment for handling operational costs and expenses."
results = classify_transaction(description)

# Save to JSON file
with open("predictions.json", "w") as f:
    json.dump(results, f, indent=4)

print("Predictions saved to predictions.json")



# --- Evaluation (Optional - if you want to include it) ---
y_pred_name = model_name.predict(X_test)
y_pred_acc = model_acc.predict(X_test)

y_pred_name_labels = np.argmax(y_pred_name, axis=1)
y_pred_acc_labels = np.argmax(y_pred_acc, axis=1)

report_name = classification_report(y_test_name, y_pred_name_labels, output_dict=True)
report_acc = classification_report(y_test_acc, y_pred_acc_labels, output_dict=True)

report_json_name = json.dumps(report_name, indent=4)
report_json_acc = json.dumps(report_acc, indent=4)

print("\nClassification Report for 'Matched_Name' (JSON):")
print(report_json_name)

print("\nClassification Report for 'Account 1' (JSON):")
print(report_json_acc)
# Out:
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Training 'Matched_Name' model...
# Epoch 1/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 50s 259ms/step - accuracy: 0.1149 - loss: 3.4889 - val_accuracy: 0.2735 - val_loss: 2.4270
# Epoch 2/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 210ms/step - accuracy: 0.2188 - loss: 2.3603 - val_accuracy: 0.5684 - val_loss: 1.5997
# Epoch 3/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 199ms/step - accuracy: 0.4897 - loss: 1.4768 - val_accuracy: 0.8713 - val_loss: 0.6653
# Epoch 4/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 214ms/step - accuracy: 0.7853 - loss: 0.7377 - val_accuracy: 0.9410 - val_loss: 0.3939
# Epoch 5/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 218ms/step - accuracy: 0.9076 - loss: 0.3781 - val_accuracy: 0.9678 - val_loss: 0.2999
# Epoch 6/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.9599 - loss: 0.2057 - val_accuracy: 0.9651 - val_loss: 0.2613
# Epoch 7/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 10s 216ms/step - accuracy: 0.9680 - loss: 0.1763 - val_accuracy: 0.9651 - val_loss: 0.2679
# Epoch 8/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s 221ms/step - accuracy: 0.9659 - loss: 0.1542 - val_accuracy: 0.9625 - val_loss: 0.2734
# Epoch 9/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 11s
50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 173ms/step - accuracy: 0.9927 - loss: 0.0453 - val_accuracy: 0.9893 - val_loss: 0.1689
# Epoch 15/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 9s 178ms/step - accuracy: 0.9887 - loss: 0.0480 - val_accuracy: 0.9866 - val_loss: 0.1648
# Epoch 16/50
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.9975 - loss: 0.0331 - val_accuracy: 0.9866 - val_loss: 0.1607
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Models saved successfully!
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Predictions saved to predictions.json
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step
#
# Classification Report for 'Matched_Name' (JSON):
# {
#     "2": {
#         "precision": 0.7777777777777778,
#         "recall": 1.0,
#         "f1-score": 0.875,
#         "support": 7.0
#     },
#     "3": {
#         "precision": 0.9354838709677419,
#         "recall": 1.0,
#         "f1-score": 0.9666666666666667,
#         "support": 29.0
#     },
#     "4": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 28.0
#     },
#     "7": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "8": {
#         "precision": 0.7692307692307693,
#         "recall": 1.0,
#         "f1-score": 0.8695652173913043,
#         "support": 10.0
#     },
#     "12": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "13": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 30.0
#     },
#     "15": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 39.0
#     },
#     "17": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "22": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 2.0
#     },
#     "23": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 34.0
#     },
#     "24": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 35.0
#     },
#     "25": {
#         "precision": 0.8421052631578947,
#         "recall": 0.9411764705882353,
#         "f1-score": 0.8888888888888888,
#         "support": 17.0
#     },
#     "27": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "28": {
#         "precision": 0.9411764705882353,
#         "recall": 1.0,
#         "f1-score": 0.9696969696969697,
#         "support": 32.0
#     },
#     "30": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "31": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 30.0
#     },
#     "32": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 2.0
#     },
#     "33": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 40.0
#     },
#     "39": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 31.0
#     },
#     "41": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 2.0
#     },
#     "accuracy": 0.967828418230563,
#     "macro avg": {
#         "precision": 0.5840844834153532,
#         "recall": 0.6162464985994398,
#         "f1-score": 0.5985627496497061,
#         "support": 373.0
#     },
#     "weighted avg": {
#         "precision": 0.9428933536925588,
#         "recall": 0.967828418230563,
#         "f1-score": 0.9544112591116903,
#         "support": 373.0
#     }
# }
#
# Classification Report for 'Account 1' (JSON):
# {
#     "0": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 29.0
#     },
#     "1": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 34.0
#     },
#     "2": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 35.0
#     },
#     "3": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 35.0
#     },
#     "5": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 32.0
#     },
#     "6": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 44.0
#     },
#     "8": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "9": {
#         "precision": 0.9230769230769231,
#         "recall": 1.0,
#         "f1-score": 0.96,
#         "support": 12.0
#     },
#     "10": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 2.0
#     },
#     "11": {
#         "precision": 0.0,
#         "recall": 0.0,
#         "f1-score": 0.0,
#         "support": 1.0
#     },
#     "13": {
#         "precision": 0.9245283018867925,
#         "recall": 0.9607843137254902,
#         "f1-score": 0.9423076923076923,
#         "support": 51.0
#     },
#     "14": {
#         "precision": 0.875,
#         "recall": 1.0,
#         "f1-score": 0.9333333333333333,
#         "support": 7.0
#     },
#     "15": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 33.0
#     },
#     "17": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 35.0
#     },
#     "18": {
#         "precision": 1.0,
#         "recall": 1.0,
#         "f1-score": 1.0,
#         "support": 22.0
#     },
#     "accuracy": 0.9839142091152815,
#     "macro avg": {
#         "precision": 0.781507014997581,
#         "recall": 0.7973856209150327,
#         "f1-score": 0.789042735042735,
#         "support": 373.0
#     },
#     "weighted avg": {
#         "precision": 0.9741363712416877,
#         "recall": 0.9839142091152815,
#         "f1-score": 0.9788499346944388,
#         "support": 373.0
#     }
# }
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **Analysis Model:-**
# * The model's performance shows strong results, with high prediction accuracies for both Matched_Name and Account 1. The Matched_Name prediction for "Nextera Energy" is highly accurate at 96.39%, indicating that the model correctly identified the entity in most cases. Other potential matches include "Myer-AUD" (1.86%) and "Haaretz" (0.82%), though these have much lower probabilities, suggesting they are less likely to be correct. For Account 1, the model predicted "Appliances" with an impressive accuracy of 99.25%, demonstrating its strong capability in classifying account types. The other top predictions include "Not Found" (0.47%) and "Dues and Subscriptions" (0.15%), which show a very low likelihood of being correct. Overall, the model performs excellently in identifying and classifying the correct entities and account types, with very high confidence in its predictions. However, the low-probability alternatives indicate that there may still be edge cases where the model could benefit from further training or data enhancement.

# %%
for i in description_list1:
    results = classify_transaction(i)
    append_to_json(results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step

# %%
description_list1
# Out:
# ['AIRBNB PAYMENTS AM76GKUXMO PPD ID: XXXXXX1428',
#  'ANZ M-BANKING FUNDS TFER                TRANSFER 642683  TO  XXXXXXXX6546568',
#  'UNIQLO USA LLC NEW YORK NY XXXX2003',
#  'LIDS HOLDINGS INC. INDIANAPOLIS IN XXXX2003',
#  'Interest Charge on Pay Over Time Purchases XXXX2003',
#  'Interest Charge on Pay Over Time Purchases XXXX2003',
#  'HEINEMANN - 8734 ARRMASCOT AU XXXX2003',
#  'DAVID JONES MACQUARISYDNEY AU XXXX2003',
#  'D J*MW-ONLINE XXX-XXX-2378 NJ XXXX2003',
#  'COMCAST CABLE COMM 800-COMCAST CO XXXX2003',
#  'BING LEE ELECTRICS PSYDNEY AU XXXX2003',
#  'ATP MEDIA WIMBLEDON GB XXXX2003',
#  'AplPay MACQUARIE NORTH RYDE AU XXXX2003',
#  'TINA MAIDS COLORADO SPRINGS CO XXXX2003',
#  'AMAZON MARKETPLACE NAMZN.COM/BILL WA XXXX2011',
#  'MACQUARIE NORTH RYDE AU XXXX2003',
#  'PARAMOUNT+ WEST HOLLYWOO CA XXXX2003',
#  'P.SKOOL.COM/CNMNT EL SEGUNDO CA XXXX2003',
#  'MY SOLO 401K FINANCCARLSBAD CA XXXX2003',
#  'MOUNTAIN VIEW ELECTRLIMON CO XXXX2003',
#  'MOUNTAIN VIEW ELECTRLIMON CO XXXX2003',
#  'MONARCH MONEY APP COVINA CA XXXX2003',
#  'Internet BPAY To American Express - Biller Code 5082 - Receipt No 3521014871',
#  'Net Tfr Received From Sav 12380903 Rec No.: 2566359082',
#  'Net Tfr Received From Sav 12380903. Rec No.:2566359082,',
#  'Direct Credit Tph 1Woo01107Royal',
#  'Visa - Coles 0968 West Ryde AU#5977439 (Ref.012701033732) Apple Pay',
#  'Visa Substock Httpsmaggiesmus#5977439 (Ref.021500042599) Apple Pay',
#  'Viso Substock Httpsmaggiesmus#5977439 (Ref.031500043529) Apple Pay',
#  'Visa Chemist Warehouse Epping AU#5977439 (Ref.022400755199) Apple Pay',
#  'Visa - Woolworths/Macquarie S/C North Ryde AU#5977439 (Ref.011601561958) Apple Pay',
#  'Visa Ls The Boothouse Balmo Mosman AU#5977439 (Ref.030701023685) Apple Pay',
#  'Visa - Smp*The Reef Food Bar Collaroy AU#5977439 (Ref.021700070387) Apple Pay',
#  'Visa - Amazon Marketplace AU Sydney South AU#5977439 (Ref.011501086029)',
#  'Direct Credit Tph - 1Woo01121Royal Atc',
#  'Visa Sq *Bonbons Bakery Carlincarlingford AU#5977439 (Ref.022401535333) Apple Pay',
#  'Visa - Aadya Laxmi Pty Ltd Baulkham Hillau#5977439 (Ref.011901370671) Apple Pay',
#  'Visa - Komi Komi Carlingford AU#5977439 (Ref.011801279048) Apple Pay',
#  'Visa Mcdonalds Macquarie North Ryde AU#5977439 (Ref.020200737301) Apple Pay',
#  'Visa - Bronte Surf Life Savin Bronte AU#5977439 (Ref.011500111179) Apple Pay',
#  'Visa - Bronte Surf Life Savin Bronte AU#5977439 (Ref.011500111178) Apple Pay',
#  'Visa Live Group/8/1 Progress Aeastwood AU#5977439 (Ref.022701643205) Apple Pay',
#  'Visa Lees Farm Eastwood AU#5977439 (Ref.022800575866) Apple Pay',
#  'Visa -Tonkotsuya Carlingford AU#5977439 (Ref.020201458678) Apple Pay',
#  'Visa Abdulaziz Radi Shellharbour AU#5977439 (Ref.022900302583) Apple Pay',
#  'Visa Coles 5791 Macquarie Pk AU#5977439 (Ref.021101410748) Apple Pay',
#  'QuickBooks Payments utilizes Rent Income for handling its financial transactions and investments.',
#  'By leveraging Door Lock & Keys, Nextera Energy ensures smooth cash flow for its business operations.',
#  'By leveraging Repairs, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses AAdvantage Aviator to manage its operations efficiently.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Myer-AUD's services.",
#  'Haaretz processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Haaretz settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Appliances account is a vital part of Myer-AUD's financial strategy.",
#  "The AAdvantage Aviator account is a vital part of QuickBooks Payments's financial strategy.",
#  "The Door Lock, Key & Materials account is a vital part of Nextera Energy's financial strategy.",
#  'By leveraging Rent Income, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'Haaretz uses Appliances to manage its operations efficiently.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'By leveraging Door Lock, Key & Materials, Haaretz ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses Door Lock & Keys to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Nextera Energy's services.",
#  'By leveraging Door Lock & Keys, Farha Roofing ensures smooth cash flow for its business operations.',
#  'Superprof settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Vanguard's services.",
#  'Haaretz uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'By leveraging Appliances, Superprof ensures smooth cash flow for its business operations.',
#  "The Repairs account reflects payments and expenditures related to Myer-AUD's services.",
#  'QuickBooks Payments uses Accounts Payable to manage its operations efficiently.',
#  'By leveraging Accounts Payable, Farha Roofing ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses Door Lock & Keys to manage its operations efficiently.',
#  'BANNERMAN ENERGY LTD utilizes Rent Income for handling its financial transactions and investments.',
#  'Farha Roofing utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'By leveraging Accounts Payable, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'By leveraging ANZ_Land Loan Offset_8143, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'SOUNDHOUND AI INC utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'Vanguard uses Accounts Payable to manage its operations efficiently.',
#  'QuickBooks Payments processes payments through Repairs for its ongoing projects.',
#  'Myer-AUD settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'By leveraging Repairs, Vanguard ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Door Lock & Keys account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  'Superprof processes payments through Door Lock & Keys for its ongoing projects.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The Accounts Payable account reflects payments and expenditures related to Myer-AUD's services.",
#  'Myer-AUD processes payments through Appliances for its ongoing projects.',
#  'SOUNDHOUND AI INC uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  'QuickBooks Payments utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Farha Roofing settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Nextera Energy utilizes Accounts Payable for handling its financial transactions and investments.',
#  'Superprof settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'Superprof settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Superprof settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'By leveraging Accounts Payable, Vanguard ensures smooth cash flow for its business operations.',
#  "The Door Lock & Keys account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  'SOUNDHOUND AI INC processes payments through AAdvantage Aviator for its ongoing projects.',
#  'Nextera Energy processes payments through Accounts Payable for its ongoing projects.',
#  'Farha Roofing utilizes Repairs for handling its financial transactions and investments.',
#  'Myer-AUD utilizes Accounts Payable for handling its financial transactions and investments.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  "The Door Lock & Keys account is a vital part of Nextera Energy's financial strategy.",
#  'QuickBooks Payments processes payments through Rent Income for its ongoing projects.',
#  'Haaretz settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'QuickBooks Payments utilizes Appliances for handling its financial transactions and investments.',
#  'Farha Roofing uses Repairs to manage its operations efficiently.',
#  "The Rent Income account reflects payments and expenditures related to Vanguard's services.",
#  'BANNERMAN ENERGY LTD processes payments through AAdvantage Aviator for its ongoing projects.',
#  'Myer-AUD utilizes Repairs for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account is a vital part of QuickBooks Payments's financial strategy.",
#  'QuickBooks Payments utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'By leveraging ANZ_Land Loan Offset_8143, Superprof ensures smooth cash flow for its business operations.',
#  'By leveraging Door Lock & Keys, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Repairs account reflects payments and expenditures related to Vanguard's services.",
#  'BANNERMAN ENERGY LTD processes payments through AAdvantage Aviator for its ongoing projects.',
#  'SOUNDHOUND AI INC uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'Vanguard processes payments through Appliances for its ongoing projects.',
#  "The Door Lock, Key & Materials account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  'Vanguard utilizes Accounts Payable for handling its financial transactions and investments.',
#  'By leveraging Repairs, Haaretz ensures smooth cash flow for its business operations.',
#  'Haaretz utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Myer-AUD uses Door Lock & Keys to manage its operations efficiently.',
#  "The Appliances account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  'QuickBooks Payments processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'SOUNDHOUND AI INC processes payments through AAdvantage Aviator for its ongoing projects.',
#  "The Repair & Maintenance - AUD account is a vital part of Superprof's financial strategy.",
#  'By leveraging AAdvantage Aviator, Superprof ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account is a vital part of Farha Roofing's financial strategy.",
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Myer-AUD uses Repairs to manage its operations efficiently.',
#  'Vanguard processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'BANNERMAN ENERGY LTD uses Repairs to manage its operations efficiently.',
#  'Superprof uses Door Lock, Key & Materials to manage its operations efficiently.',
#  "The Repair & Maintenance - AUD account is a vital part of Myer-AUD's financial strategy.",
#  'Nextera Energy uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'QuickBooks Payments utilizes Accounts Payable for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'Nextera Energy uses Appliances to manage its operations efficiently.',
#  "The Door Lock, Key & Materials account is a vital part of QuickBooks Payments's financial strategy.",
#  'Haaretz processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Vanguard processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Nextera Energy's services.",
#  "The Repair & Maintenance - AUD account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD uses Rent Income to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account is a vital part of Myer-AUD's financial strategy.",
#  'By leveraging Accounts Payable, Haaretz ensures smooth cash flow for its business operations.',
#  'Myer-AUD settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'QuickBooks Payments processes payments through Rent Income for its ongoing projects.',
#  'Haaretz utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'Myer-AUD settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  "The Repairs account is a vital part of Farha Roofing's financial strategy.",
#  'Farha Roofing utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Haaretz's services.",
#  'Haaretz uses Door Lock & Keys to manage its operations efficiently.',
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'By leveraging ANZ_Land Loan Offset_8143, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'Myer-AUD utilizes Rent Income for handling its financial transactions and investments.',
#  "The Repairs account reflects payments and expenditures related to Nextera Energy's services.",
#  'Superprof processes payments through Accounts Payable for its ongoing projects.',
#  'Superprof uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'QuickBooks Payments settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'By leveraging Door Lock, Key & Materials, Nextera Energy ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments processes payments through AAdvantage Aviator for its ongoing projects.',
#  'Superprof settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'By leveraging AAdvantage Aviator, Haaretz ensures smooth cash flow for its business operations.',
#  'Superprof settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  "The Repairs account reflects payments and expenditures related to Myer-AUD's services.",
#  'Vanguard settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  "The Door Lock & Keys account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Superprof processes payments through Accounts Payable for its ongoing projects.',
#  "The Rent Income account is a vital part of Myer-AUD's financial strategy.",
#  'Myer-AUD processes payments through Accounts Payable for its ongoing projects.',
#  'Haaretz utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'By leveraging Door Lock & Keys, Haaretz ensures smooth cash flow for its business operations.',
#  'By leveraging Repair & Maintenance - AUD, Superprof ensures smooth cash flow for its business operations.',
#  "The Repair & Maintenance - AUD account is a vital part of Nextera Energy's financial strategy.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'By leveraging Repairs, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Farha Roofing settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Nextera Energy utilizes Repairs for handling its financial transactions and investments.',
#  'By leveraging Appliances, Vanguard ensures smooth cash flow for its business operations.',
#  'Superprof uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'By leveraging ANZ_Land Loan Offset_8143, Nextera Energy ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'By leveraging Rent Income, Haaretz ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD uses Repairs to manage its operations efficiently.',
#  'Superprof uses AAdvantage Aviator to manage its operations efficiently.',
#  'Nextera Energy processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Vanguard uses AAdvantage Aviator to manage its operations efficiently.',
#  'Farha Roofing processes payments through Repairs for its ongoing projects.',
#  'BANNERMAN ENERGY LTD utilizes Accounts Payable for handling its financial transactions and investments.',
#  "The Repairs account reflects payments and expenditures related to Vanguard's services.",
#  'Vanguard settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  "The Rent Income account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  'BANNERMAN ENERGY LTD processes payments through Repairs for its ongoing projects.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Myer-AUD's services.",
#  'SOUNDHOUND AI INC processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Farha Roofing's services.",
#  'QuickBooks Payments utilizes Repairs for handling its financial transactions and investments.',
#  "The Door Lock & Keys account is a vital part of Nextera Energy's financial strategy.",
#  "The AAdvantage Aviator account reflects payments and expenditures related to Vanguard's services.",
#  'Nextera Energy uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'By leveraging Rent Income, Myer-AUD ensures smooth cash flow for its business operations.',
#  "The Rent Income account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Nextera Energy settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  "The Rent Income account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'Farha Roofing utilizes Accounts Payable for handling its financial transactions and investments.',
#  "The AAdvantage Aviator account is a vital part of Farha Roofing's financial strategy.",
#  "The Repairs account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  'SOUNDHOUND AI INC utilizes Appliances for handling its financial transactions and investments.',
#  'By leveraging Repairs, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'Myer-AUD utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  "The AAdvantage Aviator account is a vital part of Vanguard's financial strategy.",
#  'By leveraging Repair & Maintenance - AUD, Farha Roofing ensures smooth cash flow for its business operations.',
#  "The AAdvantage Aviator account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Vanguard utilizes Repairs for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'Farha Roofing utilizes Appliances for handling its financial transactions and investments.',
#  'By leveraging Accounts Payable, Myer-AUD ensures smooth cash flow for its business operations.',
#  "The Appliances account reflects payments and expenditures related to Farha Roofing's services.",
#  'SOUNDHOUND AI INC settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'By leveraging Accounts Payable, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Farha Roofing utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  "The Repairs account is a vital part of Myer-AUD's financial strategy.",
#  'SOUNDHOUND AI INC uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'SOUNDHOUND AI INC settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The Door Lock, Key & Materials account reflects payments and expenditures related to Haaretz's services.",
#  'Myer-AUD processes payments through AAdvantage Aviator for its ongoing projects.',
#  'BANNERMAN ENERGY LTD utilizes Repairs for handling its financial transactions and investments.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Nextera Energy's services.",
#  'Nextera Energy settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'By leveraging AAdvantage Aviator, Vanguard ensures smooth cash flow for its business operations.',
#  'Superprof utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Repairs account is a vital part of QuickBooks Payments's financial strategy.",
#  'Farha Roofing utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account is a vital part of Vanguard's financial strategy.",
#  "The Rent Income account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Nextera Energy utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  'Myer-AUD processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  "The Accounts Payable account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'By leveraging AAdvantage Aviator, Haaretz ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'Myer-AUD uses Appliances to manage its operations efficiently.',
#  'QuickBooks Payments uses Door Lock & Keys to manage its operations efficiently.',
#  'QuickBooks Payments utilizes Rent Income for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Repairs for its ongoing projects.',
#  "The Door Lock & Keys account is a vital part of QuickBooks Payments's financial strategy.",
#  'QuickBooks Payments processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'SOUNDHOUND AI INC utilizes Appliances for handling its financial transactions and investments.',
#  'By leveraging Appliances, Farha Roofing ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'By leveraging AAdvantage Aviator, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Door Lock, Key & Materials account reflects payments and expenditures related to Farha Roofing's services.",
#  'Farha Roofing settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'BANNERMAN ENERGY LTD utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'SOUNDHOUND AI INC processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'Superprof uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Myer-AUD's services.",
#  'SOUNDHOUND AI INC processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'By leveraging Repairs, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'By leveraging Accounts Payable, Superprof ensures smooth cash flow for its business operations.',
#  'Haaretz utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'Myer-AUD processes payments through Door Lock & Keys for its ongoing projects.',
#  "The Repair & Maintenance - AUD account is a vital part of Haaretz's financial strategy.",
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'Farha Roofing processes payments through Rent Income for its ongoing projects.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  'Haaretz utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Haaretz processes payments through Rent Income for its ongoing projects.',
#  'Vanguard uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  "The Repairs account reflects payments and expenditures related to Superprof's services.",
#  'By leveraging ANZ_Land Loan Offset_8143, Superprof ensures smooth cash flow for its business operations.',
# ...
#  'By leveraging Door Lock, Key & Materials, Nextera Energy ensures smooth cash flow for its business operations.',
#  'By leveraging Repair & Maintenance - AUD, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The AAdvantage Aviator account is a vital part of Vanguard's financial strategy.",
#  'By leveraging Repair & Maintenance - AUD, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through Accounts Payable, ensuring timely transaction processing.',
#  'QuickBooks Payments settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  'QuickBooks Payments settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  'Haaretz utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  'Vanguard uses Accounts Payable to manage its operations efficiently.',
#  'By leveraging AAdvantage Aviator, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  "The Repairs account is a vital part of Haaretz's financial strategy.",
#  "The Repairs account is a vital part of Farha Roofing's financial strategy.",
#  "The Rent Income account reflects payments and expenditures related to Vanguard's services.",
#  "The Appliances account is a vital part of Superprof's financial strategy.",
#  'By leveraging Repair & Maintenance - AUD, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  "The Repair & Maintenance - AUD account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  'Haaretz uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Farha Roofing settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'Superprof utilizes Repairs for handling its financial transactions and investments.',
#  'By leveraging Appliances, Haaretz ensures smooth cash flow for its business operations.',
#  'Superprof processes payments through Door Lock & Keys for its ongoing projects.',
#  'Vanguard utilizes Repairs for handling its financial transactions and investments.',
#  'By leveraging Rent Income, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account reflects payments and expenditures related to Farha Roofing's services.",
#  'Nextera Energy uses Rent Income to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Myer-AUD's services.",
#  'BANNERMAN ENERGY LTD uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Nextera Energy utilizes ANZ_Land Loan Offset_8143 for handling its financial transactions and investments.',
#  'Vanguard processes payments through Appliances for its ongoing projects.',
#  'QuickBooks Payments uses Appliances to manage its operations efficiently.',
#  'Superprof uses Door Lock & Keys to manage its operations efficiently.',
#  'Haaretz utilizes Door Lock & Keys for handling its financial transactions and investments.',
#  'By leveraging Repair & Maintenance - AUD, Farha Roofing ensures smooth cash flow for its business operations.',
#  "The Appliances account is a vital part of Farha Roofing's financial strategy.",
#  'SOUNDHOUND AI INC utilizes Appliances for handling its financial transactions and investments.',
#  'QuickBooks Payments settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  'QuickBooks Payments uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  "The Repairs account reflects payments and expenditures related to Vanguard's services.",
#  "The Repairs account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing uses Appliances to manage its operations efficiently.',
#  'By leveraging Door Lock & Keys, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  'Farha Roofing utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Haaretz settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'SOUNDHOUND AI INC processes payments through Rent Income for its ongoing projects.',
#  'Superprof utilizes Repair & Maintenance - AUD for handling its financial transactions and investments.',
#  'By leveraging AAdvantage Aviator, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  'By leveraging Accounts Payable, BANNERMAN ENERGY LTD ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account is a vital part of QuickBooks Payments's financial strategy.",
#  'Nextera Energy processes payments through Appliances for its ongoing projects.',
#  "The Door Lock & Keys account is a vital part of Myer-AUD's financial strategy.",
#  "The Repairs account reflects payments and expenditures related to Superprof's services.",
#  'Vanguard processes payments through Door Lock & Keys for its ongoing projects.',
#  'Farha Roofing utilizes Accounts Payable for handling its financial transactions and investments.',
#  'Myer-AUD utilizes Accounts Payable for handling its financial transactions and investments.',
#  'Myer-AUD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Appliances account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'Haaretz settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'SOUNDHOUND AI INC processes payments through Door Lock & Keys for its ongoing projects.',
#  'BANNERMAN ENERGY LTD uses Door Lock & Keys to manage its operations efficiently.',
#  'Vanguard settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'By leveraging Door Lock & Keys, Myer-AUD ensures smooth cash flow for its business operations.',
#  'Vanguard settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'By leveraging Appliances, Haaretz ensures smooth cash flow for its business operations.',
#  "The Accounts Payable account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  "The Repairs account reflects payments and expenditures related to Superprof's services.",
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Superprof's services.",
#  'QuickBooks Payments utilizes Repairs for handling its financial transactions and investments.',
#  "The Rent Income account is a vital part of Nextera Energy's financial strategy.",
#  'Haaretz utilizes Accounts Payable for handling its financial transactions and investments.',
#  'BANNERMAN ENERGY LTD uses AAdvantage Aviator to manage its operations efficiently.',
#  'Vanguard settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  "The Door Lock, Key & Materials account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  "The Appliances account reflects payments and expenditures related to Farha Roofing's services.",
#  'By leveraging Door Lock, Key & Materials, Nextera Energy ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments uses Repair & Maintenance - AUD to manage its operations efficiently.',
#  'Nextera Energy utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'Superprof processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'By leveraging Rent Income, Nextera Energy ensures smooth cash flow for its business operations.',
#  'QuickBooks Payments settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'By leveraging Rent Income, Farha Roofing ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through Appliances, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD utilizes Door Lock, Key & Materials for handling its financial transactions and investments.',
#  "The Repair & Maintenance - AUD account reflects payments and expenditures related to Nextera Energy's services.",
#  'BANNERMAN ENERGY LTD processes payments through Rent Income for its ongoing projects.',
#  "The Accounts Payable account reflects payments and expenditures related to Myer-AUD's services.",
#  "The Door Lock & Keys account reflects payments and expenditures related to QuickBooks Payments's services.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through Door Lock, Key & Materials, ensuring timely transaction processing.',
#  "The Accounts Payable account is a vital part of SOUNDHOUND AI INC's financial strategy.",
#  "The Repair & Maintenance - AUD account is a vital part of Haaretz's financial strategy.",
#  'Vanguard uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Superprof uses Appliances to manage its operations efficiently.',
#  'By leveraging Accounts Payable, Vanguard ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, Vanguard ensures smooth cash flow for its business operations.',
#  'SOUNDHOUND AI INC settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'Farha Roofing processes payments through Repairs for its ongoing projects.',
#  'SOUNDHOUND AI INC uses Door Lock & Keys to manage its operations efficiently.',
#  'SOUNDHOUND AI INC utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  "The Door Lock, Key & Materials account is a vital part of Superprof's financial strategy.",
#  'Superprof settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'By leveraging Repair & Maintenance - AUD, Myer-AUD ensures smooth cash flow for its business operations.',
#  'BANNERMAN ENERGY LTD uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'QuickBooks Payments uses Door Lock & Keys to manage its operations efficiently.',
#  'Farha Roofing uses Door Lock, Key & Materials to manage its operations efficiently.',
#  'Superprof settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  'BANNERMAN ENERGY LTD settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'Superprof processes payments through Door Lock & Keys for its ongoing projects.',
#  'Haaretz uses ANZ_Land Loan Offset_8143 to manage its operations efficiently.',
#  'Haaretz processes payments through Repair & Maintenance - AUD for its ongoing projects.',
#  'QuickBooks Payments settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Myer-AUD's services.",
#  'Myer-AUD uses Rent Income to manage its operations efficiently.',
#  'Superprof settles all vendor payments through ANZ_Land Loan Offset_8143, ensuring timely transaction processing.',
#  'QuickBooks Payments settles all vendor payments through Door Lock & Keys, ensuring timely transaction processing.',
#  "The Accounts Payable account reflects payments and expenditures related to Nextera Energy's services.",
#  'Vanguard utilizes Appliances for handling its financial transactions and investments.',
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  'By leveraging Appliances, Nextera Energy ensures smooth cash flow for its business operations.',
#  'Haaretz processes payments through Door Lock & Keys for its ongoing projects.',
#  "The Appliances account is a vital part of Farha Roofing's financial strategy.",
#  'QuickBooks Payments utilizes Appliances for handling its financial transactions and investments.',
#  'QuickBooks Payments uses Door Lock, Key & Materials to manage its operations efficiently.',
#  "The Appliances account is a vital part of Haaretz's financial strategy.",
#  'By leveraging ANZ_Land Loan Offset_8143, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'By leveraging AAdvantage Aviator, SOUNDHOUND AI INC ensures smooth cash flow for its business operations.',
#  "The Door Lock & Keys account reflects payments and expenditures related to Nextera Energy's services.",
#  'Nextera Energy settles all vendor payments through Rent Income, ensuring timely transaction processing.',
#  'Farha Roofing processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Farha Roofing settles all vendor payments through Repairs, ensuring timely transaction processing.',
#  "The Appliances account reflects payments and expenditures related to Nextera Energy's services.",
#  "The AAdvantage Aviator account reflects payments and expenditures related to Vanguard's services.",
#  'Farha Roofing uses Appliances to manage its operations efficiently.',
#  "The Door Lock & Keys account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  "The Door Lock, Key & Materials account is a vital part of Haaretz's financial strategy.",
#  'By leveraging Repairs, QuickBooks Payments ensures smooth cash flow for its business operations.',
#  'By leveraging Repair & Maintenance - AUD, Superprof ensures smooth cash flow for its business operations.',
#  'Nextera Energy uses Accounts Payable to manage its operations efficiently.',
#  "The AAdvantage Aviator account is a vital part of Haaretz's financial strategy.",
#  "The Appliances account reflects payments and expenditures related to BANNERMAN ENERGY LTD's services.",
#  "The AAdvantage Aviator account is a vital part of Vanguard's financial strategy.",
#  'BANNERMAN ENERGY LTD utilizes Door Lock, Key & Materials for handling its financial transactions and investments.',
#  'Farha Roofing uses Rent Income to manage its operations efficiently.',
#  "The ANZ_Land Loan Offset_8143 account reflects payments and expenditures related to Nextera Energy's services.",
#  'BANNERMAN ENERGY LTD processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'Farha Roofing processes payments through Door Lock, Key & Materials for its ongoing projects.',
#  'Superprof processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  "The Appliances account is a vital part of BANNERMAN ENERGY LTD's financial strategy.",
#  'Farha Roofing processes payments through ANZ_Land Loan Offset_8143 for its ongoing projects.',
#  'Myer-AUD utilizes AAdvantage Aviator for handling its financial transactions and investments.',
#  'QuickBooks Payments settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The AAdvantage Aviator account reflects payments and expenditures related to Nextera Energy's services.",
#  "The Rent Income account reflects payments and expenditures related to Vanguard's services.",
#  'BANNERMAN ENERGY LTD uses Repairs to manage its operations efficiently.',
#  'Superprof uses Repairs to manage its operations efficiently.',
#  'SOUNDHOUND AI INC uses Accounts Payable to manage its operations efficiently.',
#  'By leveraging Repair & Maintenance - AUD, Superprof ensures smooth cash flow for its business operations.',
#  "The Repairs account reflects payments and expenditures related to SOUNDHOUND AI INC's services.",
#  'BANNERMAN ENERGY LTD settles all vendor payments through AAdvantage Aviator, ensuring timely transaction processing.',
#  'QuickBooks Payments utilizes Door Lock, Key & Materials for handling its financial transactions and investments.',
#  'QuickBooks Payments settles all vendor payments through Repair & Maintenance - AUD, ensuring timely transaction processing.',
#  "The AAdvantage Aviator account is a vital part of QuickBooks Payments's financial strategy.",
#  'Superprof uses Accounts Payable to manage its operations efficiently.',
#  "The Appliances account is a vital part of Haaretz's financial strategy.",
#  ...]

# %%
description = "The Repairs account is a vital part of Haaretz's financial strategy."
results = classify_transaction(description)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step

# %%
results
# Out:
# {'description': "The Repairs account is a vital part of Haaretz's financial strategy.",
#  'predicted_matched_name': 'Haaretz (99.89%)',
#  'predicted_account': 'Repairs (99.97%)'}

# %%
# store the values
append_to_json(results)

# %% [markdown]
# # Store Output in JSON FIle

# %%
import json # call json model
import os # call os model

def append_to_json(new_result, filename='results.json'):
    """Appends a new result to a JSON file, handling file creation and list structure."""

    if not os.path.exists(filename):  # Check if the file exists
        with open(filename, 'w') as f:
            json.dump([new_result], f, indent=4)  # Create file with initial list

    else:
        with open(filename, 'r+') as f:  # Open in read and write mode ('r+')
            try:
                data = json.load(f)  # Load existing data
                if isinstance(data, list):  # Check if it's a list
                    data.append(new_result)  # Append the new result
                    f.seek(0)  # Go to the beginning of the file
                    json.dump(data, f, indent=4)  # Write the updated list
                    f.truncate()  # Remove any remaining old data (important!)
                else:
                    print(f"Warning: JSON file '{filename}' does not contain a list.  Overwriting with new list.")
                    json.dump([new_result], f, indent=4)  # Overwrite if it's not a list

            except json.JSONDecodeError:  # Handle potential JSON errors
                print(f"Warning: JSON file '{filename}' is corrupted. Overwriting with new list.")
                json.dump([new_result], f, indent=4)  # Overwrite if JSON is invalid

# %% [markdown]
# # Conclusion:
#
# **Random Forest Classification:** Random Forest Classification is an ensemble method that builds multiple decision trees and combines their predictions through majority voting, resulting in improved accuracy and reduced overfitting. It works well with high-dimensional data and is robust against noise, making it ideal for classification tasks.
#
# **Named Entity Recognition (NER):** NER is a natural language processing technique used to identify and classify entities such as names, organizations, locations, and dates in text. It is particularly useful for extracting structured information from unstructured text and is widely used in information extraction and document analysis.
#
# **Long Short-Term Memory (LSTM):** LSTM is a type of recurrent neural network designed to capture long-term dependencies in sequential data, such as time series or text. By using memory cells and gates, LSTMs can retain important information over long sequences, making them effective for tasks like speech recognition, machine translation, and sentiment analysis.

# %% [markdown]
# # Report on Challenges faced:-
#
# **Three Tables Not Correlated:**
# * When the tables aren’t directly related, merging them can be challenging. You may need to identify meaningful relationships or common features, and apply techniques like data merging, joining, or feature engineering to create a unified dataset for training.
#
# **Extra Columns:**
# * Extra columns introduce noise, which can reduce model accuracy. Feature selection techniques help eliminate irrelevant or redundant columns, allowing the model to focus on the most important features that drive predictions.
#
# **Predicting Two Output Variables:**
# * Predicting multiple variables requires handling multi-output prediction. You can either treat them as separate tasks or use models that can predict both outputs at once, such as multi-output regression or classification models.
#
# **Output in JSON Format:**
# * Converting predictions into JSON format is useful for APIs or web applications. After generating predictions, Python’s json library can be used to structure and output the results in a JSON format for easier integration.
#
# **Small Data:**
# * Small datasets limit model performance, leading to lower accuracy. Techniques like data augmentation or synthetic data generation can help enlarge the dataset, improving model generalization and reducing overfitting.
#
# **Low Accuracy:**
# * Low accuracy often stems from poor feature selection or model limitations. Enhancing data quality, experimenting with different algorithms, or applying hyperparameter tuning can help boost model performance and accuracy.

# %%
import json
import numpy as np

# Save the arrays as JSON files
with open("label_enc_name_classes.json", "w") as f:
    json.dump(label_enc_name.classes_.tolist(), f)

with open("label_enc_acc_classes.json", "w") as f:
    json.dump(label_enc_acc.classes_.tolist(), f)

# %%
# Load the classes from JSON files and convert back to numpy arrays
with open("label_enc_name_classes.json", "r") as f:
    label_enc_name.classes_ = np.array(json.load(f))

with open("label_enc_acc_classes.json", "r") as f:
    label_enc_acc.classes_ = np.array(json.load(f))

# %%
# Convert to a Python list for easier readability
print(list(label_enc_name.classes_))
print(list(label_enc_acc.classes_))
# Out:
# ['ATP Media', 'AirBnB', 'Amazon', 'Apple', 'BANNERMAN ENERGY LTD', 'BP', 'Bing Lee', 'Bonbons Bakery', 'Coles', 'Comcast', 'Costis Fresh Seafood', 'David Jones', 'Eat Street Parramatta', 'Farha Roofing', 'Football Australia Darlinghurst', 'Haaretz', 'Heinemann', 'Kmart', 'LIDS', 'Macquarie Centre', 'Monarch Money', 'My Health Food Shop', 'Myer', 'Myer-AUD', 'Nextera Energy', 'No Found', 'Parknpay', 'Petbarn', 'QuickBooks Payments', 'Roseville Bakehouse', 'Rusty Penny Brewing', 'SOUNDHOUND AI INC', 'Solanna Pty Ltd', 'Superprof', 'Target', 'Tina Maids Colorado Springs', 'Tonkotsuya', 'Trybooking', 'Uniqlo', 'Vanguard', 'White Horse Coffee', 'Woolworths Online']
# ['AAdvantage Aviator', 'ANZ_Land Loan Offset_8143', 'Accounts Payable', 'Appliances', 'Cleaning and Maintenance', 'Door Lock & Keys', 'Door Lock, Key & Materials', 'Dues and Subscriptions', 'Household:Fun/Meals/Entertainment', 'Household:Groceries', 'Household:Health,Fitness,Personal', 'Meals and Entertainment', 'Meals and Entertainmnent- Aud', 'Not Found', 'Office Supplies', 'Rent Income', 'Rental Income', 'Repair & Maintenance - AUD', 'Repairs', 'Utilities:Cable']

# %%
data = pd.read_csv("ABC.csv")
print(data.columns)
# Out:
# Index(['Unnamed: 0', 'Description', 'Matched_Name', 'Account 1'], dtype='object')

# %%
data.iloc[1,1]
# Out:
# 'ANZ M-BANKING FUNDS TFER                TRANSFER 642683  TO  XXXXXXXX6546568'

# %% [markdown]
# <p style="text-align: center; font-size: 30px; font-weight: bold;">Thank You</p>
